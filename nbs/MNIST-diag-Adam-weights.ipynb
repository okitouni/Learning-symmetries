# %%
# Imports
# %load_ext autoreload
# %aimport sym
# %autoreload 1
import os 
import torch
from torch import nn
import pytorch_lightning as pl
from pytorch_lightning.metrics.functional import accuracy
from pytorch_lightning.callbacks import ModelCheckpoint
import torchvision
from matplotlib import pyplot as plt
import numpy as np
from sklearn.metrics import confusion_matrix
from sym import LCN, ProgressBar, Classification_report, Logger
from sym.utils import utils
device = "cuda:0" if torch.cuda.is_available() else "cpu"
plt.style.use('dark_background')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
testset = torch.load("./data/testset.pt")
trainset = torch.load("./data/trainset.pt")
trainset, valset = torch.utils.data.random_split(trainset,[55000,5000])
trainloader = torch.utils.data.DataLoader(trainset, num_workers=6, batch_size=32, shuffle=True)
valloader = torch.utils.data.DataLoader(valset, batch_size=32, num_workers=6)
testloader = torch.utils.data.DataLoader(testset, batch_size=32, num_workers=6)
del testset, trainset, valset

# %%
fig, axes = plt.subplots(4, 4, sharex=True, sharey=True, figsize=(6, 6), dpi=120)
x,y = next(iter(trainloader))
for img,label, ax in zip(x,y,axes.flatten()):
    ax.imshow(img.squeeze().numpy())
    ax.set_xticks([])
    ax.set_yticks([])
plt.subplots_adjust(hspace=0, wspace=0)
fig.suptitle("Validation Data", y=.91)
# Out:
# Text(0.5, 0.91, 'Validation Data')

# %%
# Aggregate validation losses -> DONE!
# Change back to SGD -> DONE!
# Reporoduce their experiments -> DONE!
# Fix LCN Code -> DONE!
# Think about better problem statement for CNN vs LCN
# Shit on computaional separation paper (for not having large enough FCN)
# Show that the bounds are consistent
# By Friday have 5 pages

# %%
logdir = "./lightning_logs/MNIST/DIAG/ADAM/weights/"
if not os.path.exists(logdir): os.makedirs(logdir,exist_ok=True)

# %%
epochs = 10
lr = 1e-6
weight_decay=1e-3
optim = torch.optim.Adam
params = {"in_channels":1,"out_channels":10,"h":280,"w":280,"nfilters":256,"hidden":64,"kernel_size":28,
          "stride":28,"readout_activation":None}

# %%
# %autoreload

# %%
# Train the CNN 
module = sym.models.CNN(**params)
cnn = sym.models.Model(module,zeroparams=1e-5,
    optim=optim(module.parameters(),lr=lr))

# %%
# Run
pl.seed_everything(42)
bar = sym.utils.ProgressBar()
log = sym.utils.Logger(logdir, name="CNN",default_hp_metric=False)
path = logdir+f"CNN/version_{log.version}"
checkpoint_callback = ModelCheckpoint(dirpath=path,filename="weights.cpkt",save_top_k=1,monitor='val_loss',mode='min')
trainer = pl.Trainer(logger=log, gpus=1, max_epochs=epochs, progress_bar_refresh_rate=1,callbacks=[bar,checkpoint_callback])
trainer.fit(cnn,train_dataloader=trainloader,val_dataloaders=valloader)
# Out:
# Missing logger folder: ./lightning_logs/MNIST/DIAG/ADAM/weights/CNN
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name  | Type | Params
# -------------------------------
# 0 | model | CNN  | 1.8 M
# Epoch 9: 100%|##########| 1876/1876 [00:28<00:00, 65.96it/s, loss=0.011, v_num=0, val_loss=0.0104, val_acc=0.935, zero_params=1563166]
# 1

# %% [markdown]
# # LCN

# %%
# Train the LCN 
module = sym.models.LCN(**params)
lcn = sym.models.Model(module,zeroparams=1e-5,
    optim=optim(module.parameters(),lr=lr,weight_decay=weight_decay))

# %%
# Run
pl.seed_everything(42)
bar = sym.utils.ProgressBar()
log = sym.utils.Logger(logdir, name="LCN",default_hp_metric=False)
path = logdir+f"LCN/version_{log.version}"
checkpoint_callback = ModelCheckpoint(dirpath=path,filename="weights.cpkt",save_top_k=1,monitor='val_loss',mode='min')
trainer = pl.Trainer(logger=log, gpus=1, max_epochs=epochs, progress_bar_refresh_rate=1,callbacks=[bar,checkpoint_callback])
trainer.fit(lcn,train_dataloader=trainloader,val_dataloaders=valloader)
# Out:
# Missing logger folder: ./lightning_logs/MNIST/DIAG/ADAM/weights/LCN
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name  | Type | Params
# -------------------------------
# 0 | model | LCN  | 21.7 M
# Epoch 9: 100%|##########| 1876/1876 [01:27<00:00, 21.32it/s, loss=0.024, v_num=0, val_loss=0.0265, val_acc=0.826, zero_params=1.9e+7]
# 1

# %% [markdown]
# # FCN

# %%
# Train the FCN 
module = sym.models.FCN(**params)
fcn = sym.models.Model(module,zeroparams=1e-5,
    optim=optim(module.parameters(),lr=lr,weight_decay=weight_decay))

# %%
# Run
pl.seed_everything(42)
bar = sym.utils.ProgressBar()
log = sym.utils.Logger(logdir, name="FCN",default_hp_metric=False)
path = logdir+f"FCN/version_{log.version}"
checkpoint_callback = ModelCheckpoint(dirpath=path,filename="weights.cpkt",save_top_k=1,monitor='val_loss',mode='min')
trainer = pl.Trainer(logger=log, gpus=1, max_epochs=epochs, progress_bar_refresh_rate=1,callbacks=[bar,checkpoint_callback])
trainer.fit(fcn,train_dataloader=trainloader,val_dataloaders=valloader)
# Out:
# Missing logger folder: ./lightning_logs/MNIST/DIAG/ADAM/weights/FCN
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name  | Type | Params
# -------------------------------
# 0 | model | FCN  | 20.1 M
# Epoch 9: 100%|##########| 1876/1876 [00:38<00:00, 48.18it/s, loss=0.026, v_num=0, val_loss=0.0272, val_acc=0.819, zero_params=1.8e+7]
# 1

# %% [markdown]
# # These filters look weird ever since I added weight decay 1e-3
# Can we use misalignment now?

# %%
# plot
weights_cnn = next(cnn.model.parameters()).detach().cpu().squeeze()
filters_cnn = utils.minmaxnorm(weights_cnn)
fig, axes = plt.subplots(4, 4, sharex=True, sharey=True, figsize=(6, 6), dpi=120)
for img, ax in zip(filters_cnn,axes.flatten()):
    ax.imshow(img.numpy())
    ax.set_xticks([])
    ax.set_yticks([])
plt.subplots_adjust(hspace=0, wspace=0)
fig.suptitle("CNN Filters", y=.91)
# Out:
# Text(0.5, 0.91, 'CNN Filters')

# %%
weights_fcn = next(fcn.model.parameters()).detach().cpu()
filters_fcn = utils.minmaxnorm(weights_fcn)

# %%
# plot
fig, axes = plt.subplots(2, 2, sharex=True, sharey=True, figsize=(6, 6), dpi=120)
for img, ax in zip(filters_fcn[100:],axes.flatten()):
    ax.imshow(img.view(280,280).numpy())
    ax.set_xticks([])
    ax.set_yticks([])
plt.subplots_adjust(hspace=0, wspace=0)
fig.suptitle("FCN Filters", y=.91)
# Out:
# Text(0.5, 0.91, 'FCN Filters')

# %%
weights_lcn = next(lcn.model.parameters()).detach().cpu().squeeze()
weights_lcn = weights_lcn.unflatten(0,(params["nfilters"],10,10)) #get filter locations
weights_lcn = weights_lcn.permute(0,1,3,2,4) # height and width next to each other
weights_lcn = weights_lcn.flatten(1,2).flatten(2,3)

# %%
# plot
filters_lcn = utils.minmaxnorm(weights_lcn)
fig, axes = plt.subplots(2, 2, sharex=True, sharey=True, figsize=(6, 6), dpi=120)
for img, ax in zip(filters_lcn[200:],axes.flatten()):
    ax.imshow(img.numpy())
    ax.set_xticks([])
    ax.set_yticks([])
plt.subplots_adjust(hspace=0, wspace=0)
fig.suptitle("LCN Filters", y=.91)
# Out:
# Text(0.5, 0.91, 'LCN Filters')

# %% [markdown]
# # Old

# %%
# plot
fig, axes = plt.subplots(2, 2, sharex=True, sharey=True, figsize=(6, 6), dpi=120)
for img, ax in zip(filters_fcn[100:],axes.flatten()):
    ax.imshow(img.view(280,280).numpy())
    ax.set_xticks([])
    ax.set_yticks([])
plt.subplots_adjust(hspace=0, wspace=0)
fig.suptitle("FCN Filters", y=.91)
# Out:
# Text(0.5, 0.91, 'FCN Filters')

# %%
# plot
filters_lcn = utils.minmaxnorm(weights_lcn)
fig, axes = plt.subplots(2, 2, sharex=True, sharey=True, figsize=(6, 6), dpi=120)
for img, ax in zip(filters_lcn[200:],axes.flatten()):
    ax.imshow(img.numpy())
    ax.set_xticks([])
    ax.set_yticks([])
plt.subplots_adjust(hspace=0, wspace=0)
fig.suptitle("LCN Filters", y=.91)
# Out:
# Text(0.5, 0.91, 'LCN Filters')

# %% [markdown]
# # Testing

# %%
# Load weights
nfilters = 256
stride = 28
kernel_size = 28
hidden = 64
optim=torch.optim.Adam
module = sym.models.FCN(1, out_channels=10, h=280, w=280, nfilters=nfilters,hidden=hidden,
                     kernel_size=kernel_size, stride=stride, readout_activation=None)
fcn = sym.models.Model(module, optim=optim(module.parameters()))
fcn.load_from_checkpoint("lightning_logs/MNIST/DIAG/ADAM/weights/FCN/version_0/weights.cpkt-v0.ckpt", model = module, optim=optim(module.parameters()))
module = sym.models.CNN(1, out_channels=10, h=280, w=280, nfilters=nfilters,hidden=hidden,
                     kernel_size=kernel_size, stride=stride, readout_activation=None)
cnn = sym.models.Model(module,optim=optim(module.parameters()))
cnn.load_from_checkpoint("lightning_logs/MNIST/DIAG/ADAM/weights/CNN/version_0/weights.cpkt-v0.ckpt", model = module, optim=optim(module.parameters()))
module = sym.models.LCN(1, out_channels=10, h=280, w=280, nfilters=nfilters,hidden=hidden,
                     kernel_size=kernel_size, stride=stride, readout_activation=None)
lcn = sym.models.Model(module,optim=optim(module.parameters()))
lcn.load_from_checkpoint("lightning_logs/MNIST/DIAG/ADAM/weights/LCN/version_0/weights.cpkt-v0.ckpt", model=module, optim=optim(module.parameters()))
print("Models loaded successfully!")
# Out:
# Models loaded successfully!

# %%
testset_rand = torch.load("./data/testset_rand.pt")
testloader_rand = torch.utils.data.DataLoader(testset_rand, batch_size=32, num_workers=6)
del testset_rand

# %%
# train
trainer = pl.Trainer(callbacks=[sym.utils.ProgressBar()],progress_bar_refresh_rate=1,gpus=0)
cnn_tests = [trainer.test(cnn,testloader)]
lcn_tests = [trainer.test(lcn,testloader)]
fcn_tests = [trainer.test(fcn,testloader)]
cnn_tests.append(trainer.test(cnn,testloader_rand))
lcn_tests.append(trainer.test(lcn,testloader_rand))
fcn_tests.append(trainer.test(fcn,testloader_rand))
# Out:
# GPU available: True, used: False
# TPU available: False, using: 0 TPU cores
# /home/kitouni/anaconda3/envs/gnn/lib/python3.7/site-packages/pytorch_lightning/utilities/distributed.py:45: UserWarning: GPU available but not used. Set the --gpus flag when calling the script.
#   warnings.warn(*args, **kwargs)
# Testing:  95%|#########4| 18/19 [00:01<00:00,  1.77it/s]--------------------------------------------------------------------------------
# DATALOADER:0 TEST RESULTS
# {'val_acc': tensor(0.9417), 'val_loss': tensor(0.0086)}
# --------------------------------------------------------------------------------
# DATALOADER:1 TEST RESULTS
# {'val_acc': tensor(0.9688), 'val_loss': tensor(0.0063)}
# --------------------------------------------------------------------------------
# DATALOADER:2 TEST RESULTS
# {'val_acc': tensor(0.9375), 'val_loss': tensor(0.0100)}
# --------------------------------------------------------------------------------
# DATALOADER:3 TEST RESULTS
# {'val_acc': tensor(0.9688), 'val_loss': tensor(0.0022)}
# --------------------------------------------------------------------------------
# DATALOADER:4 TEST RESULTS
# {'val_acc': tensor(0.9688), 'val_loss': tensor(0.0030)}
# --------------------------------------------------------------------------------
# DATALOADER:5 TEST RESULTS
# {'val_acc': tensor(0.9688), 'val_loss': tensor(0.0043)}
# --------------------------------------------------------------------------------
# DATALOADER:6 TEST RESULTS
# {'val_acc': tensor(1.), 'val_loss': tensor(0.0013)}
# --------------------------------------------------------------------------------
# DATALOADER:7 TEST RESULTS
# {'val_acc': tensor(0.9688), 'val_loss': tensor(0.0048)}
# --------------------------------------------------------------------------------
# DATALOADER:8 TEST RESULTS
# {'val_acc': tensor(0.8750), 'val_loss': tensor(0.0177)}
# --------------------------------------------------------------------------------
# DATALOADER:9 TEST RESULTS
# {'val_acc': tensor(0.9688), 'val_loss': tensor(0.0072)}
# --------------------------------------------------------------------------------
# DATALOADER:10 TEST RESULTS
# {'val_acc': tensor(0.9062), 'val_loss': tensor(0.0097)}
# --------------------------------------------------------------------------------
# DATALOADER:11 TEST RESULTS
# {'val_acc': tensor(0.8750), 'val_loss': tensor(0.0183)}
# --------------------------------------------------------------------------------
# DATALOADER:12 TEST RESULTS
# {'val_acc': tensor(0.9688), 'val_loss': tensor(0.0101)}
# --------------------------------------------------------------------------------
# DATALOADER:13 TEST RESULTS
# {'val_acc': tensor(1.), 'val_loss': tensor(0.0014)}
# --------------------------------------------------------------------------------
# DATALOADER:14 TEST RESULTS
# {'val_acc': tensor(0.9375), 'val_loss': tensor(0.0127)}
# --------------------------------------------------------------------------------
# DATALOADER:15 TEST RESULTS
# {'val_acc': tensor(0.9062), 'val_loss': tensor(0.0131)}
# --------------------------------------------------------------------------------
# DATALOADER:16 TEST RESULTS
# {'val_acc': tensor(0.8750), 'val_loss': tensor(0.0115)}
# --------------------------------------------------------------------------------
# DATALOADER:17 TEST RESULTS
# {'val_acc': tensor(0.9688), 'val_loss': tensor(0.0081)}
# --------------------------------------------------------------------------------
# DATALOADER:18 TEST RESULTS
# {'val_acc': tensor(0.9688), 'val_loss': tensor(0.0079)}
# --------------------------------------------------------------------------------
# DATALOADER:19 TEST RESULTS
# {'val_acc': tensor(0.8333), 'val_loss': tensor(0.0164)}
# --------------------------------------------------------------------------------
# Testing: 100%|##########| 19/19 [00:01<00:00, 11.41it/s]
# Testing: 100%|##########| 19/19 [00:14<00:00,  1.49it/s]--------------------------------------------------------------------------------
# DATALOADER:0 TEST RESULTS
# {'val_acc': tensor(0.8517), 'val_loss': tensor(0.0209)}
# --------------------------------------------------------------------------------
# DATALOADER:1 TEST RESULTS
# {'val_acc': tensor(0.9062), 'val_loss': tensor(0.0110)}
# --------------------------------------------------------------------------------
# DATALOADER:2 TEST RESULTS
# {'val_acc': tensor(0.9062), 'val_loss': tensor(0.0157)}
# --------------------------------------------------------------------------------
# DATALOADER:3 TEST RESULTS
# {'val_acc': tensor(0.9062), 'val_loss': tensor(0.0174)}
# --------------------------------------------------------------------------------
# DATALOADER:4 TEST RESULTS
# {'val_acc': tensor(0.9062), 'val_loss': tensor(0.0176)}
# --------------------------------------------------------------------------------
# DATALOADER:5 TEST RESULTS
# {'val_acc': tensor(0.9375), 'val_loss': tensor(0.0101)}
# --------------------------------------------------------------------------------
# DATALOADER:6 TEST RESULTS
# {'val_acc': tensor(0.9062), 'val_loss': tensor(0.0134)}
# --------------------------------------------------------------------------------
# DATALOADER:7 TEST RESULTS
# {'val_acc': tensor(0.9062), 'val_loss': tensor(0.0139)}
# --------------------------------------------------------------------------------
# DATALOADER:8 TEST RESULTS
# {'val_acc': tensor(0.7812), 'val_loss': tensor(0.0256)}
# --------------------------------------------------------------------------------
# DATALOADER:9 TEST RESULTS
# {'val_acc': tensor(0.9062), 'val_loss': tensor(0.0163)}
# --------------------------------------------------------------------------------
# DATALOADER:10 TEST RESULTS
# {'val_acc': tensor(0.8125), 'val_loss': tensor(0.0271)}
# --------------------------------------------------------------------------------
# DATALOADER:11 TEST RESULTS
# {'val_acc': tensor(0.7812), 'val_loss': tensor(0.0294)}
# --------------------------------------------------------------------------------
# DATALOADER:12 TEST RESULTS
# {'val_acc': tensor(0.8750), 'val_loss': tensor(0.0191)}
# --------------------------------------------------------------------------------
# DATALOADER:13 TEST RESULTS
# {'val_acc': tensor(0.9062), 'val_loss': tensor(0.0145)}
# --------------------------------------------------------------------------------
# DATALOADER:14 TEST RESULTS
# {'val_acc': tensor(0.7500), 'val_loss': tensor(0.0287)}
# --------------------------------------------------------------------------------
# DATALOADER:15 TEST RESULTS
# {'val_acc': tensor(0.7812), 'val_loss': tensor(0.0275)}
# --------------------------------------------------------------------------------
# DATALOADER:16 TEST RESULTS
# {'val_acc': tensor(0.8125), 'val_loss': tensor(0.0238)}
# --------------------------------------------------------------------------------
# DATALOADER:17 TEST RESULTS
# {'val_acc': tensor(0.7500), 'val_loss': tensor(0.0351)}
# --------------------------------------------------------------------------------
# DATALOADER:18 TEST RESULTS
# {'val_acc': tensor(0.8125), 'val_loss': tensor(0.0256)}
# --------------------------------------------------------------------------------
# DATALOADER:19 TEST RESULTS
# {'val_acc': tensor(0.8333), 'val_loss': tensor(0.0272)}
# --------------------------------------------------------------------------------
# Testing: 100%|##########| 19/19 [00:14<00:00,  1.28it/s]
# Testing: 100%|##########| 19/19 [00:01<00:00,  1.79it/s]--------------------------------------------------------------------------------
# DATALOADER:0 TEST RESULTS
# {'val_acc': tensor(0.8367), 'val_loss': tensor(0.0247)}
# --------------------------------------------------------------------------------
# DATALOADER:1 TEST RESULTS
# {'val_acc': tensor(0.9375), 'val_loss': tensor(0.0095)}
# --------------------------------------------------------------------------------
# DATALOADER:2 TEST RESULTS
# {'val_acc': tensor(0.8750), 'val_loss': tensor(0.0171)}
# --------------------------------------------------------------------------------
# DATALOADER:3 TEST RESULTS
# {'val_acc': tensor(0.9062), 'val_loss': tensor(0.0164)}
# --------------------------------------------------------------------------------
# DATALOADER:4 TEST RESULTS
# {'val_acc': tensor(0.7188), 'val_loss': tensor(0.0385)}
# --------------------------------------------------------------------------------
# DATALOADER:5 TEST RESULTS
# {'val_acc': tensor(0.9375), 'val_loss': tensor(0.0119)}
# --------------------------------------------------------------------------------
# DATALOADER:6 TEST RESULTS
# {'val_acc': tensor(0.9062), 'val_loss': tensor(0.0119)}
# --------------------------------------------------------------------------------
# DATALOADER:7 TEST RESULTS
# {'val_acc': tensor(0.8438), 'val_loss': tensor(0.0270)}
# --------------------------------------------------------------------------------
# DATALOADER:8 TEST RESULTS
# {'val_acc': tensor(0.7812), 'val_loss': tensor(0.0305)}
# --------------------------------------------------------------------------------
# DATALOADER:9 TEST RESULTS
# {'val_acc': tensor(0.7812), 'val_loss': tensor(0.0300)}
# --------------------------------------------------------------------------------
# DATALOADER:10 TEST RESULTS
# {'val_acc': tensor(0.7812), 'val_loss': tensor(0.0315)}
# --------------------------------------------------------------------------------
# DATALOADER:11 TEST RESULTS
# {'val_acc': tensor(0.7500), 'val_loss': tensor(0.0380)}
# --------------------------------------------------------------------------------
# DATALOADER:12 TEST RESULTS
# {'val_acc': tensor(0.8750), 'val_loss': tensor(0.0225)}
# --------------------------------------------------------------------------------
# DATALOADER:13 TEST RESULTS
# {'val_acc': tensor(0.9375), 'val_loss': tensor(0.0140)}
# --------------------------------------------------------------------------------
# DATALOADER:14 TEST RESULTS
# {'val_acc': tensor(0.7812), 'val_loss': tensor(0.0332)}
# --------------------------------------------------------------------------------
# DATALOADER:15 TEST RESULTS
# {'val_acc': tensor(0.8125), 'val_loss': tensor(0.0343)}
# --------------------------------------------------------------------------------
# DATALOADER:16 TEST RESULTS
# {'val_acc': tensor(0.7812), 'val_loss': tensor(0.0325)}
# --------------------------------------------------------------------------------
# DATALOADER:17 TEST RESULTS
# {'val_acc': tensor(0.8750), 'val_loss': tensor(0.0212)}
# --------------------------------------------------------------------------------
# DATALOADER:18 TEST RESULTS
# {'val_acc': tensor(0.7188), 'val_loss': tensor(0.0339)}
# --------------------------------------------------------------------------------
# DATALOADER:19 TEST RESULTS
# {'val_acc': tensor(0.9167), 'val_loss': tensor(0.0124)}
# --------------------------------------------------------------------------------
# Testing: 100%|##########| 19/19 [00:01<00:00, 11.39it/s]
# Testing:  98%|#########8| 307/313 [00:04<00:00, 80.23it/s]--------------------------------------------------------------------------------
# DATALOADER:0 TEST RESULTS
# {'val_acc': tensor(0.1860), 'val_loss': tensor(0.0816)}
# --------------------------------------------------------------------------------
# DATALOADER:1 TEST RESULTS
# {'val_acc': tensor(0.0938), 'val_loss': tensor(0.0817)}
# --------------------------------------------------------------------------------
# DATALOADER:2 TEST RESULTS
# {'val_acc': tensor(0.1250), 'val_loss': tensor(0.0818)}
# --------------------------------------------------------------------------------
# DATALOADER:3 TEST RESULTS
# {'val_acc': tensor(0.1875), 'val_loss': tensor(0.0760)}
# --------------------------------------------------------------------------------
# DATALOADER:4 TEST RESULTS
# {'val_acc': tensor(0.1562), 'val_loss': tensor(0.0791)}
# --------------------------------------------------------------------------------
# DATALOADER:5 TEST RESULTS
# {'val_acc': tensor(0.1875), 'val_loss': tensor(0.0789)}
# --------------------------------------------------------------------------------
# DATALOADER:6 TEST RESULTS
# {'val_acc': tensor(0.1875), 'val_loss': tensor(0.0817)}
# --------------------------------------------------------------------------------
# DATALOADER:7 TEST RESULTS
# {'val_acc': tensor(0.1562), 'val_loss': tensor(0.0770)}
# --------------------------------------------------------------------------------
# DATALOADER:8 TEST RESULTS
# {'val_acc': tensor(0.2500), 'val_loss': tensor(0.0816)}
# --------------------------------------------------------------------------------
# DATALOADER:9 TEST RESULTS
# {'val_acc': tensor(0.2188), 'val_loss': tensor(0.0844)}
# --------------------------------------------------------------------------------
# DATALOADER:10 TEST RESULTS
# {'val_acc': tensor(0.0938), 'val_loss': tensor(0.0845)}
# --------------------------------------------------------------------------------
# DATALOADER:11 TEST RESULTS
# {'val_acc': tensor(0.1562), 'val_loss': tensor(0.0793)}
# --------------------------------------------------------------------------------
# DATALOADER:12 TEST RESULTS
# {'val_acc': tensor(0.1875), 'val_loss': tensor(0.0844)}
# --------------------------------------------------------------------------------
# DATALOADER:13 TEST RESULTS
# {'val_acc': tensor(0.2188), 'val_loss': tensor(0.0788)}
# --------------------------------------------------------------------------------
# DATALOADER:14 TEST RESULTS
# {'val_acc': tensor(0.1562), 'val_loss': tensor(0.0846)}
# --------------------------------------------------------------------------------
# DATALOADER:15 TEST RESULTS
# {'val_acc': tensor(0.2500), 'val_loss': tensor(0.0814)}
# --------------------------------------------------------------------------------
# DATALOADER:16 TEST RESULTS
# {'val_acc': tensor(0.2188), 'val_loss': tensor(0.0772)}
# --------------------------------------------------------------------------------
# DATALOADER:17 TEST RESULTS
# {'val_acc': tensor(0.2812), 'val_loss': tensor(0.0733)}
# --------------------------------------------------------------------------------
# DATALOADER:18 TEST RESULTS
# {'val_acc': tensor(0.2500), 'val_loss': tensor(0.0765)}
# --------------------------------------------------------------------------------
# DATALOADER:19 TEST RESULTS
# {'val_acc': tensor(0.3125), 'val_loss': tensor(0.0787)}
# --------------------------------------------------------------------------------
# DATALOADER:20 TEST RESULTS
# {'val_acc': tensor(0.1562), 'val_loss': tensor(0.0840)}
# --------------------------------------------------------------------------------
# DATALOADER:21 TEST RESULTS
# {'val_acc': tensor(0.2812), 'val_loss': tensor(0.0731)}
# --------------------------------------------------------------------------------
# DATALOADER:22 TEST RESULTS
# {'val_acc': tensor(0.0938), 'val_loss': tensor(0.0882)}
# --------------------------------------------------------------------------------
# DATALOADER:23 TEST RESULTS
# {'val_acc': tensor(0.2812), 'val_loss': tensor(0.0703)}
# --------------------------------------------------------------------------------
# DATALOADER:24 TEST RESULTS
# {'val_acc': tensor(0.1250), 'val_loss': tensor(0.0816)}
# --------------------------------------------------------------------------------
# DATALOADER:25 TEST RESULTS
# {'val_acc': tensor(0.1875), 'val_loss': tensor(0.0816)}
# --------------------------------------------------------------------------------
# DATALOADER:26 TEST RESULTS
# {'val_acc': tensor(0.2188), 'val_loss': tensor(0.0788)}
# --------------------------------------------------------------------------------
# DATALOADER:27 TEST RESULTS
# {'val_acc': tensor(0.1875), 'val_loss': tensor(0.0789)}
# --------------------------------------------------------------------------------
# DATALOADER:28 TEST RESULTS
# {'val_acc': tensor(0.2812), 'val_loss': tensor(0.0801)}
# --------------------------------------------------------------------------------
# DATALOADER:29 TEST RESULTS
# {'val_acc': tensor(0.1875), 'val_loss': tensor(0.0816)}
# --------------------------------------------------------------------------------
# DATALOADER:30 TEST RESULTS
# {'val_acc': tensor(0.1562), 'val_loss': tensor(0.0794)}
# --------------------------------------------------------------------------------
# DATALOADER:31 TEST RESULTS
# {'val_acc': tensor(0.0938), 'val_loss': tensor(0.0848)}
# --------------------------------------------------------------------------------
# DATALOADER:32 TEST RESULTS
# {'val_acc': tensor(0.1562), 'val_loss': tensor(0.0849)}
# --------------------------------------------------------------------------------
# DATALOADER:33 TEST RESULTS
# {'val_acc': tensor(0.1562), 'val_loss': tensor(0.0850)}
# --------------------------------------------------------------------------------
# DATALOADER:34 TEST RESULTS
# {'val_acc': tensor(0.1562), 'val_loss': tensor(0.0815)}
# --------------------------------------------------------------------------------
# DATALOADER:35 TEST RESULTS
# {'val_acc': tensor(0.1875), 'val_loss': tensor(0.0815)}
# --------------------------------------------------------------------------------
# DATALOADER:36 TEST RESULTS
# {'val_acc': tensor(0.2188), 'val_loss': tensor(0.0806)}
# --------------------------------------------------------------------------------
# DATALOADER:37 TEST RESULTS
# {'val_acc': tensor(0.1250), 'val_loss': tensor(0.0837)}
# --------------------------------------------------------------------------------
# DATALOADER:38 TEST RESULTS
# {'val_acc': tensor(0.1562), 'val_loss': tensor(0.0847)}
# --------------------------------------------------------------------------------
# DATALOADER:39 TEST RESULTS
# {'val_acc': tensor(0.1875), 'val_loss': tensor(0.0815)}
# --------------------------------------------------------------------------------
# DATALOADER:40 TEST RESULTS
# {'val_acc': tensor(0.2500), 'val_loss': tensor(0.0816)}
# --------------------------------------------------------------------------------
# DATALOADER:41 TEST RESULTS
# {'val_acc': tensor(0.3438), 'val_loss': tensor(0.0681)}
# --------------------------------------------------------------------------------
# DATALOADER:42 TEST RESULTS
# {'val_acc': tensor(0.2188), 'val_loss': tensor(0.0821)}
# --------------------------------------------------------------------------------
# DATALOADER:43 TEST RESULTS
# {'val_acc': tensor(0.1875), 'val_loss': tensor(0.0822)}
# --------------------------------------------------------------------------------
# DATALOADER:44 TEST RESULTS
# {'val_acc': tensor(0.1250), 'val_loss': tensor(0.0904)}
# --------------------------------------------------------------------------------
# DATALOADER:45 TEST RESULTS
# {'val_acc': tensor(0.1562), 'val_loss': tensor(0.0844)}
# --------------------------------------------------------------------------------
# DATALOADER:46 TEST RESULTS
# {'val_acc': tensor(0.1875), 'val_loss': tensor(0.0861)}
# --------------------------------------------------------------------------------
# DATALOADER:47 TEST RESULTS
# {'val_acc': tensor(0.1562), 'val_loss': tensor(0.0844)}
# --------------------------------------------------------------------------------
# DATALOADER:48 TEST RESULTS
# {'val_acc': tensor(0.1562), 'val_loss': tensor(0.0843)}
# --------------------------------------------------------------------------------
# DATALOADER:49 TEST RESULTS
# {'val_acc': tensor(0.2500), 'val_loss': tensor(0.0815)}
# --------------------------------------------------------------------------------
# DATALOADER:50 TEST RESULTS
# {'val_acc': tensor(0.1875), 'val_loss': tensor(0.0819)}
# --------------------------------------------------------------------------------
# DATALOADER:51 TEST RESULTS
# {'val_acc': tensor(0.1562), 'val_loss': tensor(0.0790)}
# --------------------------------------------------------------------------------
# DATALOADER:52 TEST RESULTS
# {'val_acc': tensor(0.0938), 'val_loss': tensor(0.0845)}
# --------------------------------------------------------------------------------
# DATALOADER:53 TEST RESULTS
# {'val_acc': tensor(0.2188), 'val_loss': tensor(0.0871)}
# --------------------------------------------------------------------------------
# DATALOADER:54 TEST RESULTS
# {'val_acc': tensor(0.1250), 'val_loss': tensor(0.0901)}
# --------------------------------------------------------------------------------
# DATALOADER:55 TEST RESULTS
# {'val_acc': tensor(0.1562), 'val_loss': tensor(0.0872)}
# --------------------------------------------------------------------------------
# DATALOADER:56 TEST RESULTS
# {'val_acc': tensor(0.1562), 'val_loss': tensor(0.0816)}
# --------------------------------------------------------------------------------
# DATALOADER:57 TEST RESULTS
# {'val_acc': tensor(0.2188), 'val_loss': tensor(0.0759)}
# --------------------------------------------------------------------------------
# DATALOADER:58 TEST RESULTS
# {'val_acc': tensor(0.1250), 'val_loss': tensor(0.0872)}
# --------------------------------------------------------------------------------
# DATALOADER:59 TEST RESULTS
# {'val_acc': tensor(0.1250), 'val_loss': tensor(0.0872)}
# --------------------------------------------------------------------------------
# DATALOADER:60 TEST RESULTS
# {'val_acc': tensor(0.1875), 'val_loss': tensor(0.0838)}
# --------------------------------------------------------------------------------
# DATALOADER:61 TEST RESULTS
# {'val_acc': tensor(0.1875), 'val_loss': tensor(0.0790)}
# --------------------------------------------------------------------------------
# DATALOADER:62 TEST RESULTS
# {'val_acc': tensor(0.2500), 'val_loss': tensor(0.0801)}
# --------------------------------------------------------------------------------
# DATALOADER:63 TEST RESULTS
# {'val_acc': tensor(0.2188), 'val_loss': tensor(0.0735)}
# --------------------------------------------------------------------------------
# DATALOADER:64 TEST RESULTS
# {'val_acc': tensor(0.2188), 'val_loss': tensor(0.0760)}
# --------------------------------------------------------------------------------
# DATALOADER:65 TEST RESULTS
# {'val_acc': tensor(0.1562), 'val_loss': tensor(0.0844)}
# --------------------------------------------------------------------------------
# DATALOADER:66 TEST RESULTS
# {'val_acc': tensor(0.2500), 'val_loss': tensor(0.0838)}
# --------------------------------------------------------------------------------
# DATALOADER:67 TEST RESULTS
# {'val_acc': tensor(0.1875), 'val_loss': tensor(0.0847)}
# --------------------------------------------------------------------------------
# DATALOADER:68 TEST RESULTS
# {'val_acc': tensor(0.3125), 'val_loss': tensor(0.0788)}
# --------------------------------------------------------------------------------
# DATALOADER:69 TEST RESULTS
# {'val_acc': tensor(0.2188), 'val_loss': tensor(0.0787)}
# --------------------------------------------------------------------------------
# DATALOADER:70 TEST RESULTS
# {'val_acc': tensor(0.2500), 'val_loss': tensor(0.0842)}
# --------------------------------------------------------------------------------
# DATALOADER:71 TEST RESULTS
# {'val_acc': tensor(0.1562), 'val_loss': tensor(0.0790)}
# --------------------------------------------------------------------------------
# DATALOADER:72 TEST RESULTS
# {'val_acc': tensor(0.1875), 'val_loss': tensor(0.0826)}
# --------------------------------------------------------------------------------
# DATALOADER:73 TEST RESULTS
# {'val_acc': tensor(0.0312), 'val_loss': tensor(0.0900)}
# --------------------------------------------------------------------------------
# DATALOADER:74 TEST RESULTS
# {'val_acc': tensor(0.0938), 'val_loss': tensor(0.0873)}
# --------------------------------------------------------------------------------
# DATALOADER:75 TEST RESULTS
# {'val_acc': tensor(0.2500), 'val_loss': tensor(0.0789)}
# --------------------------------------------------------------------------------
# DATALOADER:76 TEST RESULTS
# {'val_acc': tensor(0.2500), 'val_loss': tensor(0.0800)}
# --------------------------------------------------------------------------------
# DATALOADER:77 TEST RESULTS
# {'val_acc': tensor(0.0938), 'val_loss': tensor(0.0846)}
# --------------------------------------------------------------------------------
# DATALOADER:78 TEST RESULTS
# {'val_acc': tensor(0.0938), 'val_loss': tensor(0.0872)}
# --------------------------------------------------------------------------------
# DATALOADER:79 TEST RESULTS
# {'val_acc': tensor(0.1250), 'val_loss': tensor(0.0817)}
# --------------------------------------------------------------------------------
# DATALOADER:80 TEST RESULTS
# {'val_acc': tensor(0.1250), 'val_loss': tensor(0.0873)}
# --------------------------------------------------------------------------------
# DATALOADER:81 TEST RESULTS
# {'val_acc': tensor(0.1562), 'val_loss': tensor(0.0844)}
# --------------------------------------------------------------------------------
# DATALOADER:82 TEST RESULTS
# {'val_acc': tensor(0.2188), 'val_loss': tensor(0.0815)}
# --------------------------------------------------------------------------------
# DATALOADER:83 TEST RESULTS
# {'val_acc': tensor(0.1250), 'val_loss': tensor(0.0871)}
# --------------------------------------------------------------------------------
# DATALOADER:84 TEST RESULTS
# {'val_acc': tensor(0.1875), 'val_loss': tensor(0.0763)}
# --------------------------------------------------------------------------------
# DATALOADER:85 TEST RESULTS
# {'val_acc': tensor(0.1250), 'val_loss': tensor(0.0816)}
# --------------------------------------------------------------------------------
# DATALOADER:86 TEST RESULTS
# {'val_acc': tensor(0.2188), 'val_loss': tensor(0.0787)}
# --------------------------------------------------------------------------------
# DATALOADER:87 TEST RESULTS
# {'val_acc': tensor(0.1562), 'val_loss': tensor(0.0851)}
# --------------------------------------------------------------------------------
# DATALOADER:88 TEST RESULTS
# {'val_acc': tensor(0.1875), 'val_loss': tensor(0.0816)}
# --------------------------------------------------------------------------------
# DATALOADER:89 TEST RESULTS
# {'val_acc': tensor(0.1250), 'val_loss': tensor(0.0845)}
# --------------------------------------------------------------------------------
# DATALOADER:90 TEST RESULTS
# {'val_acc': tensor(0.3438), 'val_loss': tensor(0.0758)}
# --------------------------------------------------------------------------------
# DATALOADER:91 TEST RESULTS
# {'val_acc': tensor(0.2812), 'val_loss': tensor(0.0787)}
# --------------------------------------------------------------------------------
# DATALOADER:92 TEST RESULTS
# {'val_acc': tensor(0.0625), 'val_loss': tensor(0.0871)}
# --------------------------------------------------------------------------------
# DATALOADER:93 TEST RESULTS
# {'val_acc': tensor(0.2812), 'val_loss': tensor(0.0738)}
# --------------------------------------------------------------------------------
# DATALOADER:94 TEST RESULTS
# {'val_acc': tensor(0.1562), 'val_loss': tensor(0.0815)}
# --------------------------------------------------------------------------------
# DATALOADER:95 TEST RESULTS
# {'val_acc': tensor(0.1875), 'val_loss': tensor(0.0790)}
# --------------------------------------------------------------------------------
# DATALOADER:96 TEST RESULTS
# {'val_acc': tensor(0.2188), 'val_loss': tensor(0.0844)}
# --------------------------------------------------------------------------------
# DATALOADER:97 TEST RESULTS
# {'val_acc': tensor(0.2188), 'val_loss': tensor(0.0760)}
# --------------------------------------------------------------------------------
# DATALOADER:98 TEST RESULTS
# {'val_acc': tensor(0.1562), 'val_loss': tensor(0.0803)}
# --------------------------------------------------------------------------------
# DATALOADER:99 TEST RESULTS
# {'val_acc': tensor(0.2500), 'val_loss': tensor(0.0789)}
# --------------------------------------------------------------------------------
# DATALOADER:100 TEST RESULTS
# {'val_acc': tensor(0.3438), 'val_loss': tensor(0.0680)}
# --------------------------------------------------------------------------------
# DATALOADER:101 TEST RESULTS
# {'val_acc': tensor(0.2188), 'val_loss': tensor(0.0844)}
# --------------------------------------------------------------------------------
# DATALOADER:102 TEST RESULTS
# {'val_acc': tensor(0.1250), 'val_loss': tensor(0.0872)}
# --------------------------------------------------------------------------------
# DATALOADER:103 TEST RESULTS
# {'val_acc': tensor(0.2188), 'val_loss': tensor(0.0788)}
# --------------------------------------------------------------------------------
# DATALOADER:104 TEST RESULTS
# {'val_acc': tensor(0.2500), 'val_loss': tensor(0.0787)}
# --------------------------------------------------------------------------------
# DATALOADER:105 TEST RESULTS
# {'val_acc': tensor(0.1875), 'val_loss': tensor(0.0818)}
# --------------------------------------------------------------------------------
# DATALOADER:106 TEST RESULTS
# {'val_acc': tensor(0.1250), 'val_loss': tensor(0.0901)}
# --------------------------------------------------------------------------------
# DATALOADER:107 TEST RESULTS
# {'val_acc': tensor(0.1875), 'val_loss': tensor(0.0750)}
# --------------------------------------------------------------------------------
# DATALOADER:108 TEST RESULTS
# {'val_acc': tensor(0.0938), 'val_loss': tensor(0.0845)}
# --------------------------------------------------------------------------------
# DATALOADER:109 TEST RESULTS
# {'val_acc': tensor(0.1562), 'val_loss': tensor(0.0815)}
# --------------------------------------------------------------------------------
# DATALOADER:110 TEST RESULTS
# {'val_acc': tensor(0.3438), 'val_loss': tensor(0.0730)}
# --------------------------------------------------------------------------------
# DATALOADER:111 TEST RESULTS
# {'val_acc': tensor(0.0938), 'val_loss': tensor(0.0865)}
# --------------------------------------------------------------------------------
# DATALOADER:112 TEST RESULTS
# {'val_acc': tensor(0.2500), 'val_loss': tensor(0.0844)}
# --------------------------------------------------------------------------------
# DATALOADER:113 TEST RESULTS
# {'val_acc': tensor(0.1250), 'val_loss': tensor(0.0817)}
# --------------------------------------------------------------------------------
# DATALOADER:114 TEST RESULTS
# {'val_acc': tensor(0.2188), 'val_loss': tensor(0.0871)}
# --------------------------------------------------------------------------------
# DATALOADER:115 TEST RESULTS
# {'val_acc': tensor(0.1250), 'val_loss': tensor(0.0845)}
# --------------------------------------------------------------------------------
# DATALOADER:116 TEST RESULTS
# {'val_acc': tensor(0.2188), 'val_loss': tensor(0.0760)}
# --------------------------------------------------------------------------------
# DATALOADER:117 TEST RESULTS
# {'val_acc': tensor(0.2500), 'val_loss': tensor(0.0760)}
# --------------------------------------------------------------------------------
# DATALOADER:118 TEST RESULTS
# {'val_acc': tensor(0.0938), 'val_loss': tensor(0.0905)}
# --------------------------------------------------------------------------------
# DATALOADER:119 TEST RESULTS
# {'val_acc': tensor(0.2188), 'val_loss': tensor(0.0762)}
# --------------------------------------------------------------------------------
# DATALOADER:120 TEST RESULTS
# {'val_acc': tensor(0.3750), 'val_loss': tensor(0.0674)}
# --------------------------------------------------------------------------------
# DATALOADER:121 TEST RESULTS
# {'val_acc': tensor(0.1875), 'val_loss': tensor(0.0787)}
# --------------------------------------------------------------------------------
# DATALOADER:122 TEST RESULTS
# {'val_acc': tensor(0.1875), 'val_loss': tensor(0.0842)}
# --------------------------------------------------------------------------------
# DATALOADER:123 TEST RESULTS
# {'val_acc': tensor(0.2188), 'val_loss': tensor(0.0779)}
# --------------------------------------------------------------------------------
# DATALOADER:124 TEST RESULTS
# {'val_acc': tensor(0.1250), 'val_loss': tensor(0.0870)}
# --------------------------------------------------------------------------------
# DATALOADER:125 TEST RESULTS
# {'val_acc': tensor(0.1250), 'val_loss': tensor(0.0844)}
# --------------------------------------------------------------------------------
# DATALOADER:126 TEST RESULTS
# {'val_acc': tensor(0.1875), 'val_loss': tensor(0.0816)}
# --------------------------------------------------------------------------------
# DATALOADER:127 TEST RESULTS
# {'val_acc': tensor(0.1562), 'val_loss': tensor(0.0816)}
# --------------------------------------------------------------------------------
# DATALOADER:128 TEST RESULTS
# {'val_acc': tensor(0.2188), 'val_loss': tensor(0.0843)}
# --------------------------------------------------------------------------------
# DATALOADER:129 TEST RESULTS
# {'val_acc': tensor(0.3125), 'val_loss': tensor(0.0843)}
# --------------------------------------------------------------------------------
# DATALOADER:130 TEST RESULTS
# {'val_acc': tensor(0.1875), 'val_loss': tensor(0.0918)}
# --------------------------------------------------------------------------------
# DATALOADER:131 TEST RESULTS
# {'val_acc': tensor(0.1875), 'val_loss': tensor(0.0762)}
# --------------------------------------------------------------------------------
# DATALOADER:132 TEST RESULTS
# {'val_acc': tensor(0.2188), 'val_loss': tensor(0.0765)}
# --------------------------------------------------------------------------------
# DATALOADER:133 TEST RESULTS
# {'val_acc': tensor(0.2188), 'val_loss': tensor(0.0843)}
# --------------------------------------------------------------------------------
# DATALOADER:134 TEST RESULTS
# {'val_acc': tensor(0.0938), 'val_loss': tensor(0.0848)}
# --------------------------------------------------------------------------------
# DATALOADER:135 TEST RESULTS
# {'val_acc': tensor(0.1562), 'val_loss': tensor(0.0786)}
# --------------------------------------------------------------------------------
# DATALOADER:136 TEST RESULTS
# {'val_acc': tensor(0.1562), 'val_loss': tensor(0.0761)}
# --------------------------------------------------------------------------------
# DATALOADER:137 TEST RESULTS
# {'val_acc': tensor(0.2188), 'val_loss': tensor(0.0815)}
# --------------------------------------------------------------------------------
# DATALOADER:138 TEST RESULTS
# {'val_acc': tensor(0.2188), 'val_loss': tensor(0.0788)}
# --------------------------------------------------------------------------------
# DATALOADER:139 TEST RESULTS
# {'val_acc': tensor(0.1250), 'val_loss': tensor(0.0881)}
# --------------------------------------------------------------------------------
# DATALOADER:140 TEST RESULTS
# {'val_acc': tensor(0.2188), 'val_loss': tensor(0.0775)}
# --------------------------------------------------------------------------------
# DATALOADER:141 TEST RESULTS
# {'val_acc': tensor(0.2188), 'val_loss': tensor(0.0789)}
# --------------------------------------------------------------------------------
# DATALOADER:142 TEST RESULTS
# {'val_acc': tensor(0.2188), 'val_loss': tensor(0.0815)}
# --------------------------------------------------------------------------------
# DATALOADER:143 TEST RESULTS
# {'val_acc': tensor(0.2188), 'val_loss': tensor(0.0766)}
# --------------------------------------------------------------------------------
# DATALOADER:144 TEST RESULTS
# {'val_acc': tensor(0.0625), 'val_loss': tensor(0.0847)}
# --------------------------------------------------------------------------------
# DATALOADER:145 TEST RESULTS
# {'val_acc': tensor(0.1875), 'val_loss': tensor(0.0871)}
# --------------------------------------------------------------------------------
# DATALOADER:146 TEST RESULTS
# {'val_acc': tensor(0.2188), 'val_loss': tensor(0.0788)}
# --------------------------------------------------------------------------------
# DATALOADER:147 TEST RESULTS
# {'val_acc': tensor(0.0625), 'val_loss': tensor(0.0844)}
# --------------------------------------------------------------------------------
# DATALOADER:148 TEST RESULTS
# {'val_acc': tensor(0.1875), 'val_loss': tensor(0.0846)}
# --------------------------------------------------------------------------------
# DATALOADER:149 TEST RESULTS
# {'val_acc': tensor(0.2500), 'val_loss': tensor(0.0816)}
# --------------------------------------------------------------------------------
# DATALOADER:150 TEST RESULTS
# {'val_acc': tensor(0.1875), 'val_loss': tensor(0.0843)}
# --------------------------------------------------------------------------------
# DATALOADER:151 TEST RESULTS
# {'val_acc': tensor(0.2812), 'val_loss': tensor(0.0818)}
# --------------------------------------------------------------------------------
# DATALOADER:152 TEST RESULTS
# {'val_acc': tensor(0.2812), 'val_loss': tensor(0.0736)}
# --------------------------------------------------------------------------------
# DATALOADER:153 TEST RESULTS
# {'val_acc': tensor(0.1250), 'val_loss': tensor(0.0876)}
# --------------------------------------------------------------------------------
# DATALOADER:154 TEST RESULTS
# {'val_acc': tensor(0.1250), 'val_loss': tensor(0.0817)}
# --------------------------------------------------------------------------------
# DATALOADER:155 TEST RESULTS
# {'val_acc': tensor(0.1250), 'val_loss': tensor(0.0845)}
# --------------------------------------------------------------------------------
# DATALOADER:156 TEST RESULTS
# {'val_acc': tensor(0.1875), 'val_loss': tensor(0.0843)}
# --------------------------------------------------------------------------------
# DATALOADER:157 TEST RESULTS
# {'val_acc': tensor(0.1562), 'val_loss': tensor(0.0843)}
# --------------------------------------------------------------------------------
# DATALOADER:158 TEST RESULTS
# {'val_acc': tensor(0.1562), 'val_loss': tensor(0.0816)}
# --------------------------------------------------------------------------------
# DATALOADER:159 TEST RESULTS
# {'val_acc': tensor(0.2188), 'val_loss': tensor(0.0816)}
# --------------------------------------------------------------------------------
# DATALOADER:160 TEST RESULTS
# {'val_acc': tensor(0.2188), 'val_loss': tensor(0.0761)}
# --------------------------------------------------------------------------------
# DATALOADER:161 TEST RESULTS
# {'val_acc': tensor(0.1875), 'val_loss': tensor(0.0816)}
# --------------------------------------------------------------------------------
# DATALOADER:162 TEST RESULTS
# {'val_acc': tensor(0.1875), 'val_loss': tensor(0.0844)}
# --------------------------------------------------------------------------------
# DATALOADER:163 TEST RESULTS
# {'val_acc': tensor(0.2500), 'val_loss': tensor(0.0815)}
# --------------------------------------------------------------------------------
# DATALOADER:164 TEST RESULTS
# {'val_acc': tensor(0.1562), 'val_loss': tensor(0.0844)}
# --------------------------------------------------------------------------------
# DATALOADER:165 TEST RESULTS
# {'val_acc': tensor(0.1562), 'val_loss': tensor(0.0788)}
# --------------------------------------------------------------------------------
# DATALOADER:166 TEST RESULTS
# {'val_acc': tensor(0.2188), 'val_loss': tensor(0.0818)}
# --------------------------------------------------------------------------------
# DATALOADER:167 TEST RESULTS
# {'val_acc': tensor(0.1875), 'val_loss': tensor(0.0766)}
# --------------------------------------------------------------------------------
# DATALOADER:168 TEST RESULTS
# {'val_acc': tensor(0.1250), 'val_loss': tensor(0.0844)}
# --------------------------------------------------------------------------------
# DATALOADER:169 TEST RESULTS
# {'val_acc': tensor(0.2812), 'val_loss': tensor(0.0815)}
# --------------------------------------------------------------------------------
# DATALOADER:170 TEST RESULTS
# {'val_acc': tensor(0.2812), 'val_loss': tensor(0.0761)}
# --------------------------------------------------------------------------------
# DATALOADER:171 TEST RESULTS
# {'val_acc': tensor(0.0938), 'val_loss': tensor(0.0844)}
# --------------------------------------------------------------------------------
# DATALOADER:172 TEST RESULTS
# {'val_acc': tensor(0.1875), 'val_loss': tensor(0.0844)}
# --------------------------------------------------------------------------------
# DATALOADER:173 TEST RESULTS
# {'val_acc': tensor(0.1875), 'val_loss': tensor(0.0789)}
# --------------------------------------------------------------------------------
# DATALOADER:174 TEST RESULTS
# {'val_acc': tensor(0.1875), 'val_loss': tensor(0.0816)}
# --------------------------------------------------------------------------------
# DATALOADER:175 TEST RESULTS
# {'val_acc': tensor(0.1562), 'val_loss': tensor(0.0871)}
# --------------------------------------------------------------------------------
# DATALOADER:176 TEST RESULTS
# {'val_acc': tensor(0.2500), 'val_loss': tensor(0.0760)}
# --------------------------------------------------------------------------------
# DATALOADER:177 TEST RESULTS
# {'val_acc': tensor(0.2500), 'val_loss': tensor(0.0798)}
# --------------------------------------------------------------------------------
# DATALOADER:178 TEST RESULTS
# {'val_acc': tensor(0.1875), 'val_loss': tensor(0.0787)}
# --------------------------------------------------------------------------------
# DATALOADER:179 TEST RESULTS
# {'val_acc': tensor(0.2500), 'val_loss': tensor(0.0714)}
# --------------------------------------------------------------------------------
# DATALOADER:180 TEST RESULTS
# {'val_acc': tensor(0.1875), 'val_loss': tensor(0.0815)}
# --------------------------------------------------------------------------------
# DATALOADER:181 TEST RESULTS
# {'val_acc': tensor(0.2812), 'val_loss': tensor(0.0732)}
# --------------------------------------------------------------------------------
# DATALOADER:182 TEST RESULTS
# {'val_acc': tensor(0.1875), 'val_loss': tensor(0.0787)}
# --------------------------------------------------------------------------------
# DATALOADER:183 TEST RESULTS
# {'val_acc': tensor(0.0938), 'val_loss': tensor(0.0894)}
# --------------------------------------------------------------------------------
# DATALOADER:184 TEST RESULTS
# {'val_acc': tensor(0.1562), 'val_loss': tensor(0.0899)}
# --------------------------------------------------------------------------------
# DATALOADER:185 TEST RESULTS
# {'val_acc': tensor(0.2188), 'val_loss': tensor(0.0759)}
# --------------------------------------------------------------------------------
# DATALOADER:186 TEST RESULTS
# {'val_acc': tensor(0.1250), 'val_loss': tensor(0.0878)}
# --------------------------------------------------------------------------------
# DATALOADER:187 TEST RESULTS
# {'val_acc': tensor(0.1250), 'val_loss': tensor(0.0899)}
# --------------------------------------------------------------------------------
# DATALOADER:188 TEST RESULTS
# {'val_acc': tensor(0.1562), 'val_loss': tensor(0.0844)}
# --------------------------------------------------------------------------------
# DATALOADER:189 TEST RESULTS
# {'val_acc': tensor(0.1250), 'val_loss': tensor(0.0817)}
# --------------------------------------------------------------------------------
# DATALOADER:190 TEST RESULTS
# {'val_acc': tensor(0.2500), 'val_loss': tensor(0.0759)}
# --------------------------------------------------------------------------------
# DATALOADER:191 TEST RESULTS
# {'val_acc': tensor(0.0938), 'val_loss': tensor(0.0873)}
# --------------------------------------------------------------------------------
# DATALOADER:192 TEST RESULTS
# {'val_acc': tensor(0.0938), 'val_loss': tensor(0.0852)}
# --------------------------------------------------------------------------------
# DATALOADER:193 TEST RESULTS
# {'val_acc': tensor(0.2500), 'val_loss': tensor(0.0814)}
# --------------------------------------------------------------------------------
# DATALOADER:194 TEST RESULTS
# {'val_acc': tensor(0.1562), 'val_loss': tensor(0.0844)}
# --------------------------------------------------------------------------------
# DATALOADER:195 TEST RESULTS
# {'val_acc': tensor(0.1562), 'val_loss': tensor(0.0844)}
# --------------------------------------------------------------------------------
# DATALOADER:196 TEST RESULTS
# {'val_acc': tensor(0.2500), 'val_loss': tensor(0.0759)}
# --------------------------------------------------------------------------------
# DATALOADER:197 TEST RESULTS
# {'val_acc': tensor(0.2500), 'val_loss': tensor(0.0731)}
# --------------------------------------------------------------------------------
# DATALOADER:198 TEST RESULTS
# {'val_acc': tensor(0.1562), 'val_loss': tensor(0.0844)}
# --------------------------------------------------------------------------------
# DATALOADER:199 TEST RESULTS
# {'val_acc': tensor(0.2812), 'val_loss': tensor(0.0788)}
# --------------------------------------------------------------------------------
# DATALOADER:200 TEST RESULTS
# {'val_acc': tensor(0.1875), 'val_loss': tensor(0.0793)}
# --------------------------------------------------------------------------------
# DATALOADER:201 TEST RESULTS
# {'val_acc': tensor(0.1875), 'val_loss': tensor(0.0804)}
# --------------------------------------------------------------------------------
# DATALOADER:202 TEST RESULTS
# {'val_acc': tensor(0.1562), 'val_loss': tensor(0.0872)}
# --------------------------------------------------------------------------------
# DATALOADER:203 TEST RESULTS
# {'val_acc': tensor(0.2812), 'val_loss': tensor(0.0815)}
# --------------------------------------------------------------------------------
# DATALOADER:204 TEST RESULTS
# {'val_acc': tensor(0.1250), 'val_loss': tensor(0.0843)}
# --------------------------------------------------------------------------------
# DATALOADER:205 TEST RESULTS
# {'val_acc': tensor(0.0938), 'val_loss': tensor(0.0845)}
# --------------------------------------------------------------------------------
# DATALOADER:206 TEST RESULTS
# {'val_acc': tensor(0.1250), 'val_loss': tensor(0.0866)}
# --------------------------------------------------------------------------------
# DATALOADER:207 TEST RESULTS
# {'val_acc': tensor(0.1562), 'val_loss': tensor(0.0890)}
# --------------------------------------------------------------------------------
# DATALOADER:208 TEST RESULTS
# {'val_acc': tensor(0.2188), 'val_loss': tensor(0.0843)}
# --------------------------------------------------------------------------------
# DATALOADER:209 TEST RESULTS
# {'val_acc': tensor(0.1875), 'val_loss': tensor(0.0816)}
# --------------------------------------------------------------------------------
# DATALOADER:210 TEST RESULTS
# {'val_acc': tensor(0.0938), 'val_loss': tensor(0.0844)}
# --------------------------------------------------------------------------------
# DATALOADER:211 TEST RESULTS
# {'val_acc': tensor(0.0938), 'val_loss': tensor(0.0873)}
# --------------------------------------------------------------------------------
# DATALOADER:212 TEST RESULTS
# {'val_acc': tensor(0.0938), 'val_loss': tensor(0.0884)}
# --------------------------------------------------------------------------------
# DATALOADER:213 TEST RESULTS
# {'val_acc': tensor(0.2188), 'val_loss': tensor(0.0734)}
# --------------------------------------------------------------------------------
# DATALOADER:214 TEST RESULTS
# {'val_acc': tensor(0.1875), 'val_loss': tensor(0.0854)}
# --------------------------------------------------------------------------------
# DATALOADER:215 TEST RESULTS
# {'val_acc': tensor(0.2188), 'val_loss': tensor(0.0761)}
# --------------------------------------------------------------------------------
# DATALOADER:216 TEST RESULTS
# {'val_acc': tensor(0.1875), 'val_loss': tensor(0.0842)}
# --------------------------------------------------------------------------------
# DATALOADER:217 TEST RESULTS
# {'val_acc': tensor(0.1250), 'val_loss': tensor(0.0816)}
# --------------------------------------------------------------------------------
# DATALOADER:218 TEST RESULTS
# {'val_acc': tensor(0.1562), 'val_loss': tensor(0.0871)}
# --------------------------------------------------------------------------------
# DATALOADER:219 TEST RESULTS
# {'val_acc': tensor(0.0312), 'val_loss': tensor(0.0900)}
# --------------------------------------------------------------------------------
# DATALOADER:220 TEST RESULTS
# {'val_acc': tensor(0.1562), 'val_loss': tensor(0.0872)}
# --------------------------------------------------------------------------------
# DATALOADER:221 TEST RESULTS
# {'val_acc': tensor(0.2188), 'val_loss': tensor(0.0787)}
# --------------------------------------------------------------------------------
# DATALOADER:222 TEST RESULTS
# {'val_acc': tensor(0.2188), 'val_loss': tensor(0.0760)}
# --------------------------------------------------------------------------------
# DATALOADER:223 TEST RESULTS
# {'val_acc': tensor(0.2812), 'val_loss': tensor(0.0758)}
# --------------------------------------------------------------------------------
# DATALOADER:224 TEST RESULTS
# {'val_acc': tensor(0.3750), 'val_loss': tensor(0.0620)}
# --------------------------------------------------------------------------------
# DATALOADER:225 TEST RESULTS
# {'val_acc': tensor(0.1250), 'val_loss': tensor(0.0845)}
# ...
# --------------------------------------------------------------------------------
# DATALOADER:218 TEST RESULTS
# {'val_acc': tensor(0.1250), 'val_loss': tensor(0.0874)}
# --------------------------------------------------------------------------------
# DATALOADER:219 TEST RESULTS
# {'val_acc': tensor(0.1250), 'val_loss': tensor(0.0900)}
# --------------------------------------------------------------------------------
# DATALOADER:220 TEST RESULTS
# {'val_acc': tensor(0.1250), 'val_loss': tensor(0.0872)}
# --------------------------------------------------------------------------------
# DATALOADER:221 TEST RESULTS
# {'val_acc': tensor(0.1875), 'val_loss': tensor(0.0788)}
# --------------------------------------------------------------------------------
# DATALOADER:222 TEST RESULTS
# {'val_acc': tensor(0.2188), 'val_loss': tensor(0.0763)}
# --------------------------------------------------------------------------------
# DATALOADER:223 TEST RESULTS
# {'val_acc': tensor(0.1250), 'val_loss': tensor(0.0862)}
# --------------------------------------------------------------------------------
# DATALOADER:224 TEST RESULTS
# {'val_acc': tensor(0.3125), 'val_loss': tensor(0.0640)}
# --------------------------------------------------------------------------------
# DATALOADER:225 TEST RESULTS
# {'val_acc': tensor(0.1562), 'val_loss': tensor(0.0849)}
# --------------------------------------------------------------------------------
# DATALOADER:226 TEST RESULTS
# {'val_acc': tensor(0.0312), 'val_loss': tensor(0.0886)}
# --------------------------------------------------------------------------------
# DATALOADER:227 TEST RESULTS
# {'val_acc': tensor(0.1250), 'val_loss': tensor(0.0869)}
# --------------------------------------------------------------------------------
# DATALOADER:228 TEST RESULTS
# {'val_acc': tensor(0.2188), 'val_loss': tensor(0.0828)}
# --------------------------------------------------------------------------------
# DATALOADER:229 TEST RESULTS
# {'val_acc': tensor(0.2188), 'val_loss': tensor(0.0815)}
# --------------------------------------------------------------------------------
# DATALOADER:230 TEST RESULTS
# {'val_acc': tensor(0.1562), 'val_loss': tensor(0.0826)}
# --------------------------------------------------------------------------------
# DATALOADER:231 TEST RESULTS
# {'val_acc': tensor(0.1250), 'val_loss': tensor(0.0873)}
# --------------------------------------------------------------------------------
# DATALOADER:232 TEST RESULTS
# {'val_acc': tensor(0.2500), 'val_loss': tensor(0.0806)}
# --------------------------------------------------------------------------------
# DATALOADER:233 TEST RESULTS
# {'val_acc': tensor(0.1875), 'val_loss': tensor(0.0843)}
# --------------------------------------------------------------------------------
# DATALOADER:234 TEST RESULTS
# {'val_acc': tensor(0.2500), 'val_loss': tensor(0.0725)}
# --------------------------------------------------------------------------------
# DATALOADER:235 TEST RESULTS
# {'val_acc': tensor(0.2500), 'val_loss': tensor(0.0744)}
# --------------------------------------------------------------------------------
# DATALOADER:236 TEST RESULTS
# {'val_acc': tensor(0.1875), 'val_loss': tensor(0.0824)}
# --------------------------------------------------------------------------------
# DATALOADER:237 TEST RESULTS
# {'val_acc': tensor(0.1875), 'val_loss': tensor(0.0843)}
# --------------------------------------------------------------------------------
# DATALOADER:238 TEST RESULTS
# {'val_acc': tensor(0.1875), 'val_loss': tensor(0.0820)}
# --------------------------------------------------------------------------------
# DATALOADER:239 TEST RESULTS
# {'val_acc': tensor(0.1250), 'val_loss': tensor(0.0872)}
# --------------------------------------------------------------------------------
# DATALOADER:240 TEST RESULTS
# {'val_acc': tensor(0.1875), 'val_loss': tensor(0.0873)}
# --------------------------------------------------------------------------------
# DATALOADER:241 TEST RESULTS
# {'val_acc': tensor(0.2188), 'val_loss': tensor(0.0721)}
# --------------------------------------------------------------------------------
# DATALOADER:242 TEST RESULTS
# {'val_acc': tensor(0.1562), 'val_loss': tensor(0.0822)}
# --------------------------------------------------------------------------------
# DATALOADER:243 TEST RESULTS
# {'val_acc': tensor(0.1875), 'val_loss': tensor(0.0764)}
# --------------------------------------------------------------------------------
# DATALOADER:244 TEST RESULTS
# {'val_acc': tensor(0.2188), 'val_loss': tensor(0.0816)}
# --------------------------------------------------------------------------------
# DATALOADER:245 TEST RESULTS
# {'val_acc': tensor(0.2500), 'val_loss': tensor(0.0760)}
# --------------------------------------------------------------------------------
# DATALOADER:246 TEST RESULTS
# {'val_acc': tensor(0.1875), 'val_loss': tensor(0.0843)}
# --------------------------------------------------------------------------------
# DATALOADER:247 TEST RESULTS
# {'val_acc': tensor(0.1250), 'val_loss': tensor(0.0818)}
# --------------------------------------------------------------------------------
# DATALOADER:248 TEST RESULTS
# {'val_acc': tensor(0.0938), 'val_loss': tensor(0.0868)}
# --------------------------------------------------------------------------------
# DATALOADER:249 TEST RESULTS
# {'val_acc': tensor(0.1875), 'val_loss': tensor(0.0816)}
# --------------------------------------------------------------------------------
# DATALOADER:250 TEST RESULTS
# {'val_acc': tensor(0.1562), 'val_loss': tensor(0.0872)}
# --------------------------------------------------------------------------------
# DATALOADER:251 TEST RESULTS
# {'val_acc': tensor(0.0625), 'val_loss': tensor(0.0845)}
# --------------------------------------------------------------------------------
# DATALOADER:252 TEST RESULTS
# {'val_acc': tensor(0.2500), 'val_loss': tensor(0.0815)}
# --------------------------------------------------------------------------------
# DATALOADER:253 TEST RESULTS
# {'val_acc': tensor(0.1875), 'val_loss': tensor(0.0816)}
# --------------------------------------------------------------------------------
# DATALOADER:254 TEST RESULTS
# {'val_acc': tensor(0.1250), 'val_loss': tensor(0.0849)}
# --------------------------------------------------------------------------------
# DATALOADER:255 TEST RESULTS
# {'val_acc': tensor(0.1562), 'val_loss': tensor(0.0872)}
# --------------------------------------------------------------------------------
# DATALOADER:256 TEST RESULTS
# {'val_acc': tensor(0.3125), 'val_loss': tensor(0.0705)}
# --------------------------------------------------------------------------------
# DATALOADER:257 TEST RESULTS
# {'val_acc': tensor(0.1875), 'val_loss': tensor(0.0788)}
# --------------------------------------------------------------------------------
# DATALOADER:258 TEST RESULTS
# {'val_acc': tensor(0.1250), 'val_loss': tensor(0.0854)}
# --------------------------------------------------------------------------------
# DATALOADER:259 TEST RESULTS
# {'val_acc': tensor(0.1562), 'val_loss': tensor(0.0840)}
# --------------------------------------------------------------------------------
# DATALOADER:260 TEST RESULTS
# {'val_acc': tensor(0.0938), 'val_loss': tensor(0.0857)}
# --------------------------------------------------------------------------------
# DATALOADER:261 TEST RESULTS
# {'val_acc': tensor(0.1250), 'val_loss': tensor(0.0882)}
# --------------------------------------------------------------------------------
# DATALOADER:262 TEST RESULTS
# {'val_acc': tensor(0.0938), 'val_loss': tensor(0.0845)}
# --------------------------------------------------------------------------------
# DATALOADER:263 TEST RESULTS
# {'val_acc': tensor(0.1250), 'val_loss': tensor(0.0818)}
# --------------------------------------------------------------------------------
# DATALOADER:264 TEST RESULTS
# {'val_acc': tensor(0.1250), 'val_loss': tensor(0.0872)}
# --------------------------------------------------------------------------------
# DATALOADER:265 TEST RESULTS
# {'val_acc': tensor(0.0938), 'val_loss': tensor(0.0900)}
# --------------------------------------------------------------------------------
# DATALOADER:266 TEST RESULTS
# {'val_acc': tensor(0.1250), 'val_loss': tensor(0.0873)}
# --------------------------------------------------------------------------------
# DATALOADER:267 TEST RESULTS
# {'val_acc': tensor(0.0938), 'val_loss': tensor(0.0863)}
# --------------------------------------------------------------------------------
# DATALOADER:268 TEST RESULTS
# {'val_acc': tensor(0.1250), 'val_loss': tensor(0.0872)}
# --------------------------------------------------------------------------------
# DATALOADER:269 TEST RESULTS
# {'val_acc': tensor(0.1562), 'val_loss': tensor(0.0816)}
# --------------------------------------------------------------------------------
# DATALOADER:270 TEST RESULTS
# {'val_acc': tensor(0.1562), 'val_loss': tensor(0.0810)}
# --------------------------------------------------------------------------------
# DATALOADER:271 TEST RESULTS
# {'val_acc': tensor(0.3750), 'val_loss': tensor(0.0735)}
# --------------------------------------------------------------------------------
# DATALOADER:272 TEST RESULTS
# {'val_acc': tensor(0.3125), 'val_loss': tensor(0.0732)}
# --------------------------------------------------------------------------------
# DATALOADER:273 TEST RESULTS
# {'val_acc': tensor(0.1250), 'val_loss': tensor(0.0845)}
# --------------------------------------------------------------------------------
# DATALOADER:274 TEST RESULTS
# {'val_acc': tensor(0.1875), 'val_loss': tensor(0.0816)}
# --------------------------------------------------------------------------------
# DATALOADER:275 TEST RESULTS
# {'val_acc': tensor(0.1875), 'val_loss': tensor(0.0816)}
# --------------------------------------------------------------------------------
# DATALOADER:276 TEST RESULTS
# {'val_acc': tensor(0.1250), 'val_loss': tensor(0.0872)}
# --------------------------------------------------------------------------------
# DATALOADER:277 TEST RESULTS
# {'val_acc': tensor(0.2188), 'val_loss': tensor(0.0871)}
# --------------------------------------------------------------------------------
# DATALOADER:278 TEST RESULTS
# {'val_acc': tensor(0.2812), 'val_loss': tensor(0.0675)}
# --------------------------------------------------------------------------------
# DATALOADER:279 TEST RESULTS
# {'val_acc': tensor(0.0625), 'val_loss': tensor(0.0906)}
# --------------------------------------------------------------------------------
# DATALOADER:280 TEST RESULTS
# {'val_acc': tensor(0.1250), 'val_loss': tensor(0.0844)}
# --------------------------------------------------------------------------------
# DATALOADER:281 TEST RESULTS
# {'val_acc': tensor(0.2188), 'val_loss': tensor(0.0788)}
# --------------------------------------------------------------------------------
# DATALOADER:282 TEST RESULTS
# {'val_acc': tensor(0.0625), 'val_loss': tensor(0.0904)}
# --------------------------------------------------------------------------------
# DATALOADER:283 TEST RESULTS
# {'val_acc': tensor(0.0938), 'val_loss': tensor(0.0845)}
# --------------------------------------------------------------------------------
# DATALOADER:284 TEST RESULTS
# {'val_acc': tensor(0.1875), 'val_loss': tensor(0.0788)}
# --------------------------------------------------------------------------------
# DATALOADER:285 TEST RESULTS
# {'val_acc': tensor(0.2500), 'val_loss': tensor(0.0788)}
# --------------------------------------------------------------------------------
# DATALOADER:286 TEST RESULTS
# {'val_acc': tensor(0.1562), 'val_loss': tensor(0.0816)}
# --------------------------------------------------------------------------------
# DATALOADER:287 TEST RESULTS
# {'val_acc': tensor(0.1250), 'val_loss': tensor(0.0872)}
# --------------------------------------------------------------------------------
# DATALOADER:288 TEST RESULTS
# {'val_acc': tensor(0.1562), 'val_loss': tensor(0.0838)}
# --------------------------------------------------------------------------------
# DATALOADER:289 TEST RESULTS
# {'val_acc': tensor(0.2500), 'val_loss': tensor(0.0734)}
# --------------------------------------------------------------------------------
# DATALOADER:290 TEST RESULTS
# {'val_acc': tensor(0.1875), 'val_loss': tensor(0.0822)}
# --------------------------------------------------------------------------------
# DATALOADER:291 TEST RESULTS
# {'val_acc': tensor(0.1562), 'val_loss': tensor(0.0816)}
# --------------------------------------------------------------------------------
# DATALOADER:292 TEST RESULTS
# {'val_acc': tensor(0.2500), 'val_loss': tensor(0.0814)}
# --------------------------------------------------------------------------------
# DATALOADER:293 TEST RESULTS
# {'val_acc': tensor(0.1875), 'val_loss': tensor(0.0816)}
# --------------------------------------------------------------------------------
# DATALOADER:294 TEST RESULTS
# {'val_acc': tensor(0.1875), 'val_loss': tensor(0.0841)}
# --------------------------------------------------------------------------------
# DATALOADER:295 TEST RESULTS
# {'val_acc': tensor(0.1562), 'val_loss': tensor(0.0844)}
# --------------------------------------------------------------------------------
# DATALOADER:296 TEST RESULTS
# {'val_acc': tensor(0.0312), 'val_loss': tensor(0.0873)}
# --------------------------------------------------------------------------------
# DATALOADER:297 TEST RESULTS
# {'val_acc': tensor(0.2500), 'val_loss': tensor(0.0815)}
# --------------------------------------------------------------------------------
# DATALOADER:298 TEST RESULTS
# {'val_acc': tensor(0.2500), 'val_loss': tensor(0.0759)}
# --------------------------------------------------------------------------------
# DATALOADER:299 TEST RESULTS
# {'val_acc': tensor(0.0938), 'val_loss': tensor(0.0843)}
# --------------------------------------------------------------------------------
# DATALOADER:300 TEST RESULTS
# {'val_acc': tensor(0.1250), 'val_loss': tensor(0.0874)}
# --------------------------------------------------------------------------------
# DATALOADER:301 TEST RESULTS
# {'val_acc': tensor(0.2188), 'val_loss': tensor(0.0841)}
# --------------------------------------------------------------------------------
# DATALOADER:302 TEST RESULTS
# {'val_acc': tensor(0.1250), 'val_loss': tensor(0.0818)}
# --------------------------------------------------------------------------------
# DATALOADER:303 TEST RESULTS
# {'val_acc': tensor(0.1250), 'val_loss': tensor(0.0872)}
# --------------------------------------------------------------------------------
# DATALOADER:304 TEST RESULTS
# {'val_acc': tensor(0.1562), 'val_loss': tensor(0.0844)}
# --------------------------------------------------------------------------------
# DATALOADER:305 TEST RESULTS
# {'val_acc': tensor(0.2500), 'val_loss': tensor(0.0827)}
# --------------------------------------------------------------------------------
# DATALOADER:306 TEST RESULTS
# {'val_acc': tensor(0.0938), 'val_loss': tensor(0.0900)}
# --------------------------------------------------------------------------------
# DATALOADER:307 TEST RESULTS
# {'val_acc': tensor(0.0625), 'val_loss': tensor(0.0873)}
# --------------------------------------------------------------------------------
# DATALOADER:308 TEST RESULTS
# {'val_acc': tensor(0.1875), 'val_loss': tensor(0.0828)}
# --------------------------------------------------------------------------------
# DATALOADER:309 TEST RESULTS
# {'val_acc': tensor(0.1250), 'val_loss': tensor(0.0867)}
# --------------------------------------------------------------------------------
# DATALOADER:310 TEST RESULTS
# {'val_acc': tensor(0.0938), 'val_loss': tensor(0.0844)}
# --------------------------------------------------------------------------------
# DATALOADER:311 TEST RESULTS
# {'val_acc': tensor(0.1562), 'val_loss': tensor(0.0823)}
# --------------------------------------------------------------------------------
# DATALOADER:312 TEST RESULTS
# {'val_acc': tensor(0.1875), 'val_loss': tensor(0.0791)}
# --------------------------------------------------------------------------------
# DATALOADER:313 TEST RESULTS
# {'val_acc': tensor(0.2500), 'val_loss': tensor(0.0799)}
# --------------------------------------------------------------------------------
# Testing: 100%|##########| 313/313 [00:05<00:00, 56.09it/s]

# %%
# s
fcn_acc_diag = np.mean([x["val_acc"] for x in fcn_tests[0]])
fcn_acc_rand = np.mean([x["val_acc"] for x in fcn_tests[1]])
cnn_acc_diag = np.mean([x["val_acc"] for x in cnn_tests[0]])
cnn_acc_rand = np.mean([x["val_acc"] for x in cnn_tests[1]])
lcn_acc_diag = np.mean([x["val_acc"] for x in lcn_tests[0]])
lcn_acc_rand = np.mean([x["val_acc"] for x in lcn_tests[1]])
print(f"CNN accuracy on diag test data:   {cnn_acc_diag:<6.3f}")
print(f"CNN accuracy on sparse test data: {cnn_acc_rand:<6.3f}")
print(f"LCN accuracy on diag test data:   {lcn_acc_diag:<6.3f}")
print(f"LCN accuracy on sparse test data: {lcn_acc_rand:<6.3f}")
print(f"FCN accuracy on diag test data:   {fcn_acc_diag:<6.3f}")
print(f"FCN accuracy on sparse test data: {fcn_acc_rand:<6.3f}")
# Out:
# CNN accuracy on diag test data:   0.940
# CNN accuracy on sparse test data: 0.186
# LCN accuracy on diag test data:   0.851
# LCN accuracy on sparse test data: 0.171
# FCN accuracy on diag test data:   0.838
# FCN accuracy on sparse test data: 0.169
