# %%
# Imports
# %load_ext autoreload
# %aimport sym
# %autoreload 1
import os 
import torch
from torch import nn
import pytorch_lightning as pl
from pytorch_lightning.metrics.functional import accuracy
from pytorch_lightning.callbacks import ModelCheckpoint
import torchvision
from matplotlib import pyplot as plt
import numpy as np
from sklearn.metrics import confusion_matrix
from sym import LCN, ProgressBar, Classification_report, Logger
from sym.utils import utils
device = "cuda:0" if torch.cuda.is_available() else "cpu"
plt.style.use('dark_background')

# %%
testset = torch.load("./data/testset.pt")
trainset = torch.load("./data/trainset.pt")
trainset, valset = torch.utils.data.random_split(trainset,[55000,5000])
trainloader = torch.utils.data.DataLoader(trainset, num_workers=6, batch_size=32, shuffle=True)
valloader = torch.utils.data.DataLoader(valset, batch_size=32, num_workers=6)
testloader = torch.utils.data.DataLoader(testset, batch_size=32, num_workers=6)
del testset, trainset, valset

# %%
fig, axes = plt.subplots(4, 4, sharex=True, sharey=True, figsize=(6, 6), dpi=120)
x,y = next(iter(trainloader))
for img,label, ax in zip(x,y,axes.flatten()):
    ax.imshow(img.squeeze().numpy())
    ax.set_xticks([])
    ax.set_yticks([])
plt.subplots_adjust(hspace=0, wspace=0)
fig.suptitle("Validation Data", y=.91)
# Out:
# Text(0.5, 0.91, 'Validation Data')

# %%
# Aggregate validation losses -> DONE!
# Change back to SGD -> DONE!
# Reporoduce their experiments -> DONE!
# Fix LCN Code -> DONE!
# Think about better problem statement for CNN vs LCN
# Shit on computaional separation paper (for not having large enough FCN)
# Show that the bounds are consistent
# By Friday have 5 pages

# %%
logdir = "./lightning_logs/MNIST/DIAG-POOL/Adam/"
if not os.path.exists(logdir): os.makedirs(logdir,exist_ok=True)
epochs = 10
nfilters = 256
stride = 28
kernel_size = 28
hidden = 64
epochs = 10
lr = 1e-6
weight_decay=1e-3
optim = torch.optim.Adam
params = {"in_channels":1,"out_channels":10,"h":280,"w":280,"nfilters":256,"hidden":64,"kernel_size":28,"invar_reduction":"max",
          "stride":28,"readout_activation":None}

# %%
# Train the CNN 
module = sym.models.CNN(**params)
cnn = sym.models.Model(module,zeroparams=1e-5,
    optim=optim(module.parameters(),lr=lr))

# %%
# Run
pl.seed_everything(42)
bar = sym.utils.ProgressBar()
log = sym.utils.Logger(logdir, name="CNN",default_hp_metric=False)
path = logdir+f"CNN/version_{log.version}"
checkpoint_callback = ModelCheckpoint(dirpath=path,filename="weights.cpkt",save_top_k=1,monitor='val_loss',mode='min')
trainer = pl.Trainer(logger=log, gpus=1, max_epochs=epochs, progress_bar_refresh_rate=1,callbacks=[bar,checkpoint_callback])
trainer.fit(cnn,train_dataloader=trainloader,val_dataloaders=valloader)
# Out:
# Missing logger folder: ./lightning_logs/MNIST/DIAG-POOL/Adam/CNN
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name  | Type | Params
# -------------------------------
# 0 | model | CNN  | 218 K
# Epoch 9: 100%|##########| 1876/1876 [00:24<00:00, 77.05it/s, loss=0.178, v_num=0, val_loss=0.179, val_acc=0.107, zero_params=61]
# 1

# %% [markdown]
# # LCN

# %%
# Train the LCN 
module = sym.models.LCN(**params)
lcn = sym.models.Model(module,zeroparams=1e-5,
    optim=optim(module.parameters(),lr=lr,weight_decay=weight_decay))

# %%
# Run
pl.seed_everything(42)
bar = sym.utils.ProgressBar()
log = sym.utils.Logger(logdir, name="LCN",default_hp_metric=False)
path = logdir+f"LCN/version_{log.version}"
checkpoint_callback = ModelCheckpoint(dirpath=path,filename="weights.cpkt",save_top_k=1,monitor='val_loss',mode='min')
trainer = pl.Trainer(logger=log, gpus=1, max_epochs=epochs, progress_bar_refresh_rate=1,callbacks=[bar,checkpoint_callback])
trainer.fit(lcn,train_dataloader=trainloader,val_dataloaders=valloader)
# Out:
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name  | Type | Params
# -------------------------------
# 0 | model | LCN  | 20.1 M
# Epoch 9: 100%|##########| 1876/1876 [01:28<00:00, 21.25it/s, loss=0.019, v_num=1, val_loss=0.0238, val_acc=0.84, zero_params=1.81e+7]
# 1

# %%
weights_lcn = next(lcn.model.parameters()).detach().cpu().squeeze()
weights_lcn = weights_lcn.unflatten(0,(nfilters,10,10)) #get filter locations
weights_lcn = weights_lcn.permute(0,1,3,2,4) # height and width next to each other
weights_lcn = weights_lcn.flatten(1,2).flatten(2,3)

# %%
filters_lcn = utils.minmaxnorm(weights_lcn)
fig, axes = plt.subplots(2, 2, sharex=True, sharey=True, figsize=(6, 6), dpi=120)
for img, ax in zip(filters_lcn[200:],axes.flatten()):
    ax.imshow(img.numpy())
    ax.set_xticks([])
    ax.set_yticks([])
plt.subplots_adjust(hspace=0, wspace=0)
fig.suptitle("LCN Filters", y=.91)
# Out:
# Text(0.5, 0.91, 'LCN Filters')

# %% [markdown]
# # Testing

# %%
# Load weights
nfilters = 256
stride = 28
kernel_size = 28
hidden = 64
# module = sym.models.FCN(1, out_channels=10, h=280, w=280, nfilters=nfilters,hidden=hidden,
#                      kernel_size=kernel_size, stride=stride, readout_activation=None)
# fcn = sym.models.Model(module, optim=optim(module.parameters()))
# fcn.load_from_checkpoint("lightning_logs/MNIST/DIAG-POOL/Adadelta//version_0/weights.cpkt-v0.ckpt", model = module, optim=optim(module.parameters()))
module = sym.models.CNN(1, out_channels=10, h=280, w=280, nfilters=nfilters,hidden=hidden,invar_reduction="max",
                     kernel_size=kernel_size, stride=stride, readout_activation=None)
cnn = sym.models.Model(module)
cnn.load_from_checkpoint("lightning_logs/MNIST/DIAG-POOL/Adadelta/CNN/version_0/weights.cpkt-v0.ckpt", model = module, optim=optim(module.parameters()))
module = sym.models.LCN(1, out_channels=10, h=280, w=280, nfilters=nfilters,hidden=hidden,invar_reduction="max",
                     kernel_size=kernel_size, stride=stride, readout_activation=None)
lcn = sym.models.Model(module)
lcn.load_from_checkpoint("lightning_logs/MNIST/DIAG-POOL/Adadelta/LCN/version_0/weights.cpkt-v0.ckpt", model=module, optim=optim(module.parameters()))
print("Models loaded successfully!")
# Out:
# Models loaded successfully!

# %%
testset_rand = torch.load("./data/testset_rand.pt")
testloader_rand = torch.utils.data.DataLoader(testset_rand, batch_size=32, num_workers=6)
del testset_rand

# %%
trainer = pl.Trainer(callbacks=[bar],gpus=0)
cnn_tests = [trainer.test(cnn,testloader)]
lcn_tests = [trainer.test(lcn,testloader)]
# fcn_tests = [trainer.test(fcn,testloader)]
cnn_tests.append(trainer.test(cnn,testloader_rand))
lcn_tests.append(trainer.test(lcn,testloader_rand))
# fcn_tests.append(trainer.test(fcn,testloader_rand))
# Out:
# GPU available: True, used: False
# TPU available: False, using: 0 TPU cores
# Testing: 0it [00:00, ?it/s]
# /home/kitouni/anaconda3/envs/gnn/lib/python3.7/site-packages/pytorch_lightning/utilities/distributed.py:45: UserWarning: GPU available but not used. Set the --gpus flag when calling the script.
#   warnings.warn(*args, **kwargs)
# Testing:  58%|#####7    | 11/19 [00:01<00:09,  1.23s/it]--------------------------------------------------------------------------------
# DATALOADER:0 TEST RESULTS
# {'val_acc': tensor(0.8483), 'val_loss': tensor(0.0227)}
# --------------------------------------------------------------------------------
# DATALOADER:1 TEST RESULTS
# {'val_acc': tensor(0.9062), 'val_loss': tensor(0.0140)}
# --------------------------------------------------------------------------------
# DATALOADER:2 TEST RESULTS
# {'val_acc': tensor(0.8125), 'val_loss': tensor(0.0244)}
# --------------------------------------------------------------------------------
# DATALOADER:3 TEST RESULTS
# {'val_acc': tensor(0.9375), 'val_loss': tensor(0.0096)}
# --------------------------------------------------------------------------------
# DATALOADER:4 TEST RESULTS
# {'val_acc': tensor(0.8750), 'val_loss': tensor(0.0189)}
# --------------------------------------------------------------------------------
# DATALOADER:5 TEST RESULTS
# {'val_acc': tensor(0.7812), 'val_loss': tensor(0.0312)}
# --------------------------------------------------------------------------------
# DATALOADER:6 TEST RESULTS
# {'val_acc': tensor(0.8438), 'val_loss': tensor(0.0255)}
# --------------------------------------------------------------------------------
# DATALOADER:7 TEST RESULTS
# {'val_acc': tensor(0.8125), 'val_loss': tensor(0.0269)}
# --------------------------------------------------------------------------------
# DATALOADER:8 TEST RESULTS
# {'val_acc': tensor(0.7812), 'val_loss': tensor(0.0311)}
# --------------------------------------------------------------------------------
# DATALOADER:9 TEST RESULTS
# {'val_acc': tensor(0.9062), 'val_loss': tensor(0.0163)}
# --------------------------------------------------------------------------------
# DATALOADER:10 TEST RESULTS
# {'val_acc': tensor(0.8125), 'val_loss': tensor(0.0245)}
# --------------------------------------------------------------------------------
# DATALOADER:11 TEST RESULTS
# {'val_acc': tensor(0.8125), 'val_loss': tensor(0.0276)}
# --------------------------------------------------------------------------------
# DATALOADER:12 TEST RESULTS
# {'val_acc': tensor(0.7812), 'val_loss': tensor(0.0291)}
# --------------------------------------------------------------------------------
# DATALOADER:13 TEST RESULTS
# {'val_acc': tensor(0.8438), 'val_loss': tensor(0.0251)}
# --------------------------------------------------------------------------------
# DATALOADER:14 TEST RESULTS
# {'val_acc': tensor(0.9062), 'val_loss': tensor(0.0205)}
# --------------------------------------------------------------------------------
# DATALOADER:15 TEST RESULTS
# {'val_acc': tensor(0.8438), 'val_loss': tensor(0.0242)}
# --------------------------------------------------------------------------------
# DATALOADER:16 TEST RESULTS
# {'val_acc': tensor(0.8438), 'val_loss': tensor(0.0263)}
# --------------------------------------------------------------------------------
# DATALOADER:17 TEST RESULTS
# {'val_acc': tensor(0.9062), 'val_loss': tensor(0.0164)}
# --------------------------------------------------------------------------------
# DATALOADER:18 TEST RESULTS
# {'val_acc': tensor(0.8750), 'val_loss': tensor(0.0198)}
# --------------------------------------------------------------------------------
# DATALOADER:19 TEST RESULTS
# {'val_acc': tensor(0.8333), 'val_loss': tensor(0.0199)}
# --------------------------------------------------------------------------------
# Testing: 100%|##########| 19/19 [00:02<00:00,  8.12it/s]
# Testing: 100%|##########| 19/19 [00:12<00:00,  1.89it/s]--------------------------------------------------------------------------------
# DATALOADER:0 TEST RESULTS
# {'val_acc': tensor(0.7900), 'val_loss': tensor(0.0309)}
# --------------------------------------------------------------------------------
# DATALOADER:1 TEST RESULTS
# {'val_acc': tensor(0.8750), 'val_loss': tensor(0.0151)}
# --------------------------------------------------------------------------------
# DATALOADER:2 TEST RESULTS
# {'val_acc': tensor(0.7500), 'val_loss': tensor(0.0384)}
# --------------------------------------------------------------------------------
# DATALOADER:3 TEST RESULTS
# {'val_acc': tensor(0.8438), 'val_loss': tensor(0.0224)}
# --------------------------------------------------------------------------------
# DATALOADER:4 TEST RESULTS
# {'val_acc': tensor(0.7812), 'val_loss': tensor(0.0322)}
# --------------------------------------------------------------------------------
# DATALOADER:5 TEST RESULTS
# {'val_acc': tensor(0.9062), 'val_loss': tensor(0.0200)}
# --------------------------------------------------------------------------------
# DATALOADER:6 TEST RESULTS
# {'val_acc': tensor(0.8438), 'val_loss': tensor(0.0225)}
# --------------------------------------------------------------------------------
# DATALOADER:7 TEST RESULTS
# {'val_acc': tensor(0.8125), 'val_loss': tensor(0.0258)}
# --------------------------------------------------------------------------------
# DATALOADER:8 TEST RESULTS
# {'val_acc': tensor(0.7188), 'val_loss': tensor(0.0386)}
# --------------------------------------------------------------------------------
# DATALOADER:9 TEST RESULTS
# {'val_acc': tensor(0.8750), 'val_loss': tensor(0.0148)}
# --------------------------------------------------------------------------------
# DATALOADER:10 TEST RESULTS
# {'val_acc': tensor(0.6875), 'val_loss': tensor(0.0447)}
# --------------------------------------------------------------------------------
# DATALOADER:11 TEST RESULTS
# {'val_acc': tensor(0.8438), 'val_loss': tensor(0.0291)}
# --------------------------------------------------------------------------------
# DATALOADER:12 TEST RESULTS
# {'val_acc': tensor(0.7500), 'val_loss': tensor(0.0357)}
# --------------------------------------------------------------------------------
# DATALOADER:13 TEST RESULTS
# {'val_acc': tensor(0.8125), 'val_loss': tensor(0.0290)}
# --------------------------------------------------------------------------------
# DATALOADER:14 TEST RESULTS
# {'val_acc': tensor(0.8125), 'val_loss': tensor(0.0223)}
# --------------------------------------------------------------------------------
# DATALOADER:15 TEST RESULTS
# {'val_acc': tensor(0.7188), 'val_loss': tensor(0.0466)}
# --------------------------------------------------------------------------------
# DATALOADER:16 TEST RESULTS
# {'val_acc': tensor(0.6250), 'val_loss': tensor(0.0567)}
# --------------------------------------------------------------------------------
# DATALOADER:17 TEST RESULTS
# {'val_acc': tensor(0.7500), 'val_loss': tensor(0.0277)}
# --------------------------------------------------------------------------------
# DATALOADER:18 TEST RESULTS
# {'val_acc': tensor(0.7812), 'val_loss': tensor(0.0370)}
# --------------------------------------------------------------------------------
# DATALOADER:19 TEST RESULTS
# {'val_acc': tensor(0.8333), 'val_loss': tensor(0.0274)}
# --------------------------------------------------------------------------------
# Testing: 100%|##########| 19/19 [00:12<00:00,  1.47it/s]
# Testing: 100%|#########9| 312/313 [00:05<00:00, 88.17it/s]--------------------------------------------------------------------------------
# DATALOADER:0 TEST RESULTS
# {'val_acc': tensor(0.8588), 'val_loss': tensor(0.0206)}
# --------------------------------------------------------------------------------
# DATALOADER:1 TEST RESULTS
# {'val_acc': tensor(0.9062), 'val_loss': tensor(0.0140)}
# --------------------------------------------------------------------------------
# DATALOADER:2 TEST RESULTS
# {'val_acc': tensor(0.8125), 'val_loss': tensor(0.0244)}
# --------------------------------------------------------------------------------
# DATALOADER:3 TEST RESULTS
# {'val_acc': tensor(0.9375), 'val_loss': tensor(0.0096)}
# --------------------------------------------------------------------------------
# DATALOADER:4 TEST RESULTS
# {'val_acc': tensor(0.8750), 'val_loss': tensor(0.0189)}
# --------------------------------------------------------------------------------
# DATALOADER:5 TEST RESULTS
# {'val_acc': tensor(0.7812), 'val_loss': tensor(0.0312)}
# --------------------------------------------------------------------------------
# DATALOADER:6 TEST RESULTS
# {'val_acc': tensor(0.8438), 'val_loss': tensor(0.0255)}
# --------------------------------------------------------------------------------
# DATALOADER:7 TEST RESULTS
# {'val_acc': tensor(0.8125), 'val_loss': tensor(0.0269)}
# --------------------------------------------------------------------------------
# DATALOADER:8 TEST RESULTS
# {'val_acc': tensor(0.7812), 'val_loss': tensor(0.0311)}
# --------------------------------------------------------------------------------
# DATALOADER:9 TEST RESULTS
# {'val_acc': tensor(0.9062), 'val_loss': tensor(0.0163)}
# --------------------------------------------------------------------------------
# DATALOADER:10 TEST RESULTS
# {'val_acc': tensor(0.8125), 'val_loss': tensor(0.0245)}
# --------------------------------------------------------------------------------
# DATALOADER:11 TEST RESULTS
# {'val_acc': tensor(0.8125), 'val_loss': tensor(0.0276)}
# --------------------------------------------------------------------------------
# DATALOADER:12 TEST RESULTS
# {'val_acc': tensor(0.7812), 'val_loss': tensor(0.0291)}
# --------------------------------------------------------------------------------
# DATALOADER:13 TEST RESULTS
# {'val_acc': tensor(0.8438), 'val_loss': tensor(0.0251)}
# --------------------------------------------------------------------------------
# DATALOADER:14 TEST RESULTS
# {'val_acc': tensor(0.9062), 'val_loss': tensor(0.0205)}
# --------------------------------------------------------------------------------
# DATALOADER:15 TEST RESULTS
# {'val_acc': tensor(0.8438), 'val_loss': tensor(0.0242)}
# --------------------------------------------------------------------------------
# DATALOADER:16 TEST RESULTS
# {'val_acc': tensor(0.8438), 'val_loss': tensor(0.0263)}
# --------------------------------------------------------------------------------
# DATALOADER:17 TEST RESULTS
# {'val_acc': tensor(0.9062), 'val_loss': tensor(0.0164)}
# --------------------------------------------------------------------------------
# DATALOADER:18 TEST RESULTS
# {'val_acc': tensor(0.8750), 'val_loss': tensor(0.0198)}
# --------------------------------------------------------------------------------
# DATALOADER:19 TEST RESULTS
# {'val_acc': tensor(0.8438), 'val_loss': tensor(0.0198)}
# --------------------------------------------------------------------------------
# DATALOADER:20 TEST RESULTS
# {'val_acc': tensor(0.8438), 'val_loss': tensor(0.0196)}
# --------------------------------------------------------------------------------
# DATALOADER:21 TEST RESULTS
# {'val_acc': tensor(0.9375), 'val_loss': tensor(0.0133)}
# --------------------------------------------------------------------------------
# DATALOADER:22 TEST RESULTS
# {'val_acc': tensor(0.8438), 'val_loss': tensor(0.0280)}
# --------------------------------------------------------------------------------
# DATALOADER:23 TEST RESULTS
# {'val_acc': tensor(0.8438), 'val_loss': tensor(0.0250)}
# --------------------------------------------------------------------------------
# DATALOADER:24 TEST RESULTS
# {'val_acc': tensor(0.8750), 'val_loss': tensor(0.0185)}
# --------------------------------------------------------------------------------
# DATALOADER:25 TEST RESULTS
# {'val_acc': tensor(0.8125), 'val_loss': tensor(0.0277)}
# --------------------------------------------------------------------------------
# DATALOADER:26 TEST RESULTS
# {'val_acc': tensor(0.9062), 'val_loss': tensor(0.0107)}
# --------------------------------------------------------------------------------
# DATALOADER:27 TEST RESULTS
# {'val_acc': tensor(0.9062), 'val_loss': tensor(0.0161)}
# --------------------------------------------------------------------------------
# DATALOADER:28 TEST RESULTS
# {'val_acc': tensor(0.9375), 'val_loss': tensor(0.0107)}
# --------------------------------------------------------------------------------
# DATALOADER:29 TEST RESULTS
# {'val_acc': tensor(0.9062), 'val_loss': tensor(0.0126)}
# --------------------------------------------------------------------------------
# DATALOADER:30 TEST RESULTS
# {'val_acc': tensor(0.7500), 'val_loss': tensor(0.0395)}
# --------------------------------------------------------------------------------
# DATALOADER:31 TEST RESULTS
# {'val_acc': tensor(0.8438), 'val_loss': tensor(0.0206)}
# --------------------------------------------------------------------------------
# DATALOADER:32 TEST RESULTS
# {'val_acc': tensor(0.9062), 'val_loss': tensor(0.0169)}
# --------------------------------------------------------------------------------
# DATALOADER:33 TEST RESULTS
# {'val_acc': tensor(0.8438), 'val_loss': tensor(0.0205)}
# --------------------------------------------------------------------------------
# DATALOADER:34 TEST RESULTS
# {'val_acc': tensor(0.7812), 'val_loss': tensor(0.0312)}
# --------------------------------------------------------------------------------
# DATALOADER:35 TEST RESULTS
# {'val_acc': tensor(0.7188), 'val_loss': tensor(0.0352)}
# --------------------------------------------------------------------------------
# DATALOADER:36 TEST RESULTS
# {'val_acc': tensor(0.8125), 'val_loss': tensor(0.0278)}
# --------------------------------------------------------------------------------
# DATALOADER:37 TEST RESULTS
# {'val_acc': tensor(0.9062), 'val_loss': tensor(0.0148)}
# --------------------------------------------------------------------------------
# DATALOADER:38 TEST RESULTS
# {'val_acc': tensor(0.8750), 'val_loss': tensor(0.0168)}
# --------------------------------------------------------------------------------
# DATALOADER:39 TEST RESULTS
# {'val_acc': tensor(0.6875), 'val_loss': tensor(0.0465)}
# --------------------------------------------------------------------------------
# DATALOADER:40 TEST RESULTS
# {'val_acc': tensor(0.8125), 'val_loss': tensor(0.0271)}
# --------------------------------------------------------------------------------
# DATALOADER:41 TEST RESULTS
# {'val_acc': tensor(0.8125), 'val_loss': tensor(0.0236)}
# --------------------------------------------------------------------------------
# DATALOADER:42 TEST RESULTS
# {'val_acc': tensor(0.7812), 'val_loss': tensor(0.0324)}
# --------------------------------------------------------------------------------
# DATALOADER:43 TEST RESULTS
# {'val_acc': tensor(0.8750), 'val_loss': tensor(0.0142)}
# --------------------------------------------------------------------------------
# DATALOADER:44 TEST RESULTS
# {'val_acc': tensor(0.7812), 'val_loss': tensor(0.0327)}
# --------------------------------------------------------------------------------
# DATALOADER:45 TEST RESULTS
# {'val_acc': tensor(0.8750), 'val_loss': tensor(0.0152)}
# --------------------------------------------------------------------------------
# DATALOADER:46 TEST RESULTS
# {'val_acc': tensor(0.7188), 'val_loss': tensor(0.0348)}
# --------------------------------------------------------------------------------
# DATALOADER:47 TEST RESULTS
# {'val_acc': tensor(0.8438), 'val_loss': tensor(0.0236)}
# --------------------------------------------------------------------------------
# DATALOADER:48 TEST RESULTS
# {'val_acc': tensor(0.8438), 'val_loss': tensor(0.0250)}
# --------------------------------------------------------------------------------
# DATALOADER:49 TEST RESULTS
# {'val_acc': tensor(0.8438), 'val_loss': tensor(0.0222)}
# --------------------------------------------------------------------------------
# DATALOADER:50 TEST RESULTS
# {'val_acc': tensor(0.8750), 'val_loss': tensor(0.0237)}
# --------------------------------------------------------------------------------
# DATALOADER:51 TEST RESULTS
# {'val_acc': tensor(0.8750), 'val_loss': tensor(0.0216)}
# --------------------------------------------------------------------------------
# DATALOADER:52 TEST RESULTS
# {'val_acc': tensor(0.8125), 'val_loss': tensor(0.0265)}
# --------------------------------------------------------------------------------
# DATALOADER:53 TEST RESULTS
# {'val_acc': tensor(0.7500), 'val_loss': tensor(0.0378)}
# --------------------------------------------------------------------------------
# DATALOADER:54 TEST RESULTS
# {'val_acc': tensor(0.8125), 'val_loss': tensor(0.0246)}
# --------------------------------------------------------------------------------
# DATALOADER:55 TEST RESULTS
# {'val_acc': tensor(0.8438), 'val_loss': tensor(0.0246)}
# --------------------------------------------------------------------------------
# DATALOADER:56 TEST RESULTS
# {'val_acc': tensor(0.8750), 'val_loss': tensor(0.0205)}
# --------------------------------------------------------------------------------
# DATALOADER:57 TEST RESULTS
# {'val_acc': tensor(0.9375), 'val_loss': tensor(0.0140)}
# --------------------------------------------------------------------------------
# DATALOADER:58 TEST RESULTS
# {'val_acc': tensor(0.8750), 'val_loss': tensor(0.0184)}
# --------------------------------------------------------------------------------
# DATALOADER:59 TEST RESULTS
# {'val_acc': tensor(0.7500), 'val_loss': tensor(0.0341)}
# --------------------------------------------------------------------------------
# DATALOADER:60 TEST RESULTS
# {'val_acc': tensor(0.7812), 'val_loss': tensor(0.0327)}
# --------------------------------------------------------------------------------
# DATALOADER:61 TEST RESULTS
# {'val_acc': tensor(0.8750), 'val_loss': tensor(0.0255)}
# --------------------------------------------------------------------------------
# DATALOADER:62 TEST RESULTS
# {'val_acc': tensor(0.7812), 'val_loss': tensor(0.0295)}
# --------------------------------------------------------------------------------
# DATALOADER:63 TEST RESULTS
# {'val_acc': tensor(0.8438), 'val_loss': tensor(0.0224)}
# --------------------------------------------------------------------------------
# DATALOADER:64 TEST RESULTS
# {'val_acc': tensor(0.6875), 'val_loss': tensor(0.0492)}
# --------------------------------------------------------------------------------
# DATALOADER:65 TEST RESULTS
# {'val_acc': tensor(0.7500), 'val_loss': tensor(0.0373)}
# --------------------------------------------------------------------------------
# DATALOADER:66 TEST RESULTS
# {'val_acc': tensor(0.7500), 'val_loss': tensor(0.0254)}
# --------------------------------------------------------------------------------
# DATALOADER:67 TEST RESULTS
# {'val_acc': tensor(0.7188), 'val_loss': tensor(0.0388)}
# --------------------------------------------------------------------------------
# DATALOADER:68 TEST RESULTS
# {'val_acc': tensor(0.9375), 'val_loss': tensor(0.0119)}
# --------------------------------------------------------------------------------
# DATALOADER:69 TEST RESULTS
# {'val_acc': tensor(0.7812), 'val_loss': tensor(0.0322)}
# --------------------------------------------------------------------------------
# DATALOADER:70 TEST RESULTS
# {'val_acc': tensor(0.8750), 'val_loss': tensor(0.0209)}
# --------------------------------------------------------------------------------
# DATALOADER:71 TEST RESULTS
# {'val_acc': tensor(0.9375), 'val_loss': tensor(0.0108)}
# --------------------------------------------------------------------------------
# DATALOADER:72 TEST RESULTS
# {'val_acc': tensor(0.8125), 'val_loss': tensor(0.0340)}
# --------------------------------------------------------------------------------
# DATALOADER:73 TEST RESULTS
# {'val_acc': tensor(0.9062), 'val_loss': tensor(0.0136)}
# --------------------------------------------------------------------------------
# DATALOADER:74 TEST RESULTS
# {'val_acc': tensor(0.8750), 'val_loss': tensor(0.0146)}
# --------------------------------------------------------------------------------
# DATALOADER:75 TEST RESULTS
# {'val_acc': tensor(0.8438), 'val_loss': tensor(0.0298)}
# --------------------------------------------------------------------------------
# DATALOADER:76 TEST RESULTS
# {'val_acc': tensor(0.8125), 'val_loss': tensor(0.0294)}
# --------------------------------------------------------------------------------
# DATALOADER:77 TEST RESULTS
# {'val_acc': tensor(0.8750), 'val_loss': tensor(0.0171)}
# --------------------------------------------------------------------------------
# DATALOADER:78 TEST RESULTS
# {'val_acc': tensor(0.8750), 'val_loss': tensor(0.0153)}
# --------------------------------------------------------------------------------
# DATALOADER:79 TEST RESULTS
# {'val_acc': tensor(0.8750), 'val_loss': tensor(0.0195)}
# --------------------------------------------------------------------------------
# DATALOADER:80 TEST RESULTS
# {'val_acc': tensor(0.7188), 'val_loss': tensor(0.0399)}
# --------------------------------------------------------------------------------
# DATALOADER:81 TEST RESULTS
# {'val_acc': tensor(0.7812), 'val_loss': tensor(0.0279)}
# --------------------------------------------------------------------------------
# DATALOADER:82 TEST RESULTS
# {'val_acc': tensor(0.8125), 'val_loss': tensor(0.0297)}
# --------------------------------------------------------------------------------
# DATALOADER:83 TEST RESULTS
# {'val_acc': tensor(0.8438), 'val_loss': tensor(0.0229)}
# --------------------------------------------------------------------------------
# DATALOADER:84 TEST RESULTS
# {'val_acc': tensor(0.8438), 'val_loss': tensor(0.0242)}
# --------------------------------------------------------------------------------
# DATALOADER:85 TEST RESULTS
# {'val_acc': tensor(0.8750), 'val_loss': tensor(0.0185)}
# --------------------------------------------------------------------------------
# DATALOADER:86 TEST RESULTS
# {'val_acc': tensor(0.8750), 'val_loss': tensor(0.0175)}
# --------------------------------------------------------------------------------
# DATALOADER:87 TEST RESULTS
# {'val_acc': tensor(0.8125), 'val_loss': tensor(0.0247)}
# --------------------------------------------------------------------------------
# DATALOADER:88 TEST RESULTS
# {'val_acc': tensor(0.8125), 'val_loss': tensor(0.0324)}
# --------------------------------------------------------------------------------
# DATALOADER:89 TEST RESULTS
# {'val_acc': tensor(0.8438), 'val_loss': tensor(0.0187)}
# --------------------------------------------------------------------------------
# DATALOADER:90 TEST RESULTS
# {'val_acc': tensor(0.8750), 'val_loss': tensor(0.0167)}
# --------------------------------------------------------------------------------
# DATALOADER:91 TEST RESULTS
# {'val_acc': tensor(0.8750), 'val_loss': tensor(0.0149)}
# --------------------------------------------------------------------------------
# DATALOADER:92 TEST RESULTS
# {'val_acc': tensor(0.8125), 'val_loss': tensor(0.0293)}
# --------------------------------------------------------------------------------
# DATALOADER:93 TEST RESULTS
# {'val_acc': tensor(0.7500), 'val_loss': tensor(0.0350)}
# --------------------------------------------------------------------------------
# DATALOADER:94 TEST RESULTS
# {'val_acc': tensor(0.7812), 'val_loss': tensor(0.0289)}
# --------------------------------------------------------------------------------
# DATALOADER:95 TEST RESULTS
# {'val_acc': tensor(0.9375), 'val_loss': tensor(0.0103)}
# --------------------------------------------------------------------------------
# DATALOADER:96 TEST RESULTS
# {'val_acc': tensor(0.9062), 'val_loss': tensor(0.0135)}
# --------------------------------------------------------------------------------
# DATALOADER:97 TEST RESULTS
# {'val_acc': tensor(0.8438), 'val_loss': tensor(0.0239)}
# --------------------------------------------------------------------------------
# DATALOADER:98 TEST RESULTS
# {'val_acc': tensor(0.7812), 'val_loss': tensor(0.0284)}
# --------------------------------------------------------------------------------
# DATALOADER:99 TEST RESULTS
# {'val_acc': tensor(0.9062), 'val_loss': tensor(0.0162)}
# --------------------------------------------------------------------------------
# DATALOADER:100 TEST RESULTS
# {'val_acc': tensor(0.9062), 'val_loss': tensor(0.0151)}
# --------------------------------------------------------------------------------
# DATALOADER:101 TEST RESULTS
# {'val_acc': tensor(0.9062), 'val_loss': tensor(0.0112)}
# --------------------------------------------------------------------------------
# DATALOADER:102 TEST RESULTS
# {'val_acc': tensor(0.9375), 'val_loss': tensor(0.0095)}
# --------------------------------------------------------------------------------
# DATALOADER:103 TEST RESULTS
# {'val_acc': tensor(0.8438), 'val_loss': tensor(0.0218)}
# --------------------------------------------------------------------------------
# DATALOADER:104 TEST RESULTS
# {'val_acc': tensor(0.9062), 'val_loss': tensor(0.0155)}
# --------------------------------------------------------------------------------
# DATALOADER:105 TEST RESULTS
# {'val_acc': tensor(0.8125), 'val_loss': tensor(0.0314)}
# --------------------------------------------------------------------------------
# DATALOADER:106 TEST RESULTS
# {'val_acc': tensor(0.9062), 'val_loss': tensor(0.0125)}
# --------------------------------------------------------------------------------
# DATALOADER:107 TEST RESULTS
# {'val_acc': tensor(0.8750), 'val_loss': tensor(0.0189)}
# --------------------------------------------------------------------------------
# DATALOADER:108 TEST RESULTS
# {'val_acc': tensor(0.9688), 'val_loss': tensor(0.0066)}
# --------------------------------------------------------------------------------
# DATALOADER:109 TEST RESULTS
# {'val_acc': tensor(0.8438), 'val_loss': tensor(0.0215)}
# --------------------------------------------------------------------------------
# DATALOADER:110 TEST RESULTS
# {'val_acc': tensor(0.9062), 'val_loss': tensor(0.0138)}
# --------------------------------------------------------------------------------
# DATALOADER:111 TEST RESULTS
# {'val_acc': tensor(0.9062), 'val_loss': tensor(0.0167)}
# --------------------------------------------------------------------------------
# DATALOADER:112 TEST RESULTS
# {'val_acc': tensor(0.7812), 'val_loss': tensor(0.0339)}
# --------------------------------------------------------------------------------
# DATALOADER:113 TEST RESULTS
# {'val_acc': tensor(0.8438), 'val_loss': tensor(0.0260)}
# --------------------------------------------------------------------------------
# DATALOADER:114 TEST RESULTS
# {'val_acc': tensor(0.8125), 'val_loss': tensor(0.0256)}
# --------------------------------------------------------------------------------
# DATALOADER:115 TEST RESULTS
# {'val_acc': tensor(0.8438), 'val_loss': tensor(0.0193)}
# --------------------------------------------------------------------------------
# DATALOADER:116 TEST RESULTS
# {'val_acc': tensor(0.8750), 'val_loss': tensor(0.0155)}
# --------------------------------------------------------------------------------
# DATALOADER:117 TEST RESULTS
# {'val_acc': tensor(0.8750), 'val_loss': tensor(0.0123)}
# --------------------------------------------------------------------------------
# DATALOADER:118 TEST RESULTS
# {'val_acc': tensor(0.7812), 'val_loss': tensor(0.0318)}
# --------------------------------------------------------------------------------
# DATALOADER:119 TEST RESULTS
# {'val_acc': tensor(0.7500), 'val_loss': tensor(0.0363)}
# --------------------------------------------------------------------------------
# DATALOADER:120 TEST RESULTS
# {'val_acc': tensor(0.6250), 'val_loss': tensor(0.0523)}
# --------------------------------------------------------------------------------
# DATALOADER:121 TEST RESULTS
# {'val_acc': tensor(0.7500), 'val_loss': tensor(0.0318)}
# --------------------------------------------------------------------------------
# DATALOADER:122 TEST RESULTS
# {'val_acc': tensor(0.8438), 'val_loss': tensor(0.0247)}
# --------------------------------------------------------------------------------
# DATALOADER:123 TEST RESULTS
# {'val_acc': tensor(0.7812), 'val_loss': tensor(0.0313)}
# --------------------------------------------------------------------------------
# DATALOADER:124 TEST RESULTS
# {'val_acc': tensor(0.8125), 'val_loss': tensor(0.0289)}
# --------------------------------------------------------------------------------
# DATALOADER:125 TEST RESULTS
# {'val_acc': tensor(0.8750), 'val_loss': tensor(0.0178)}
# --------------------------------------------------------------------------------
# DATALOADER:126 TEST RESULTS
# {'val_acc': tensor(0.8438), 'val_loss': tensor(0.0210)}
# --------------------------------------------------------------------------------
# DATALOADER:127 TEST RESULTS
# {'val_acc': tensor(0.8750), 'val_loss': tensor(0.0198)}
# --------------------------------------------------------------------------------
# DATALOADER:128 TEST RESULTS
# {'val_acc': tensor(0.7188), 'val_loss': tensor(0.0408)}
# --------------------------------------------------------------------------------
# DATALOADER:129 TEST RESULTS
# {'val_acc': tensor(0.9062), 'val_loss': tensor(0.0162)}
# --------------------------------------------------------------------------------
# DATALOADER:130 TEST RESULTS
# {'val_acc': tensor(0.8750), 'val_loss': tensor(0.0209)}
# --------------------------------------------------------------------------------
# DATALOADER:131 TEST RESULTS
# {'val_acc': tensor(0.9062), 'val_loss': tensor(0.0180)}
# --------------------------------------------------------------------------------
# DATALOADER:132 TEST RESULTS
# {'val_acc': tensor(0.8438), 'val_loss': tensor(0.0199)}
# --------------------------------------------------------------------------------
# DATALOADER:133 TEST RESULTS
# {'val_acc': tensor(0.7812), 'val_loss': tensor(0.0324)}
# --------------------------------------------------------------------------------
# DATALOADER:134 TEST RESULTS
# {'val_acc': tensor(0.8750), 'val_loss': tensor(0.0202)}
# --------------------------------------------------------------------------------
# DATALOADER:135 TEST RESULTS
# {'val_acc': tensor(0.6562), 'val_loss': tensor(0.0518)}
# --------------------------------------------------------------------------------
# DATALOADER:136 TEST RESULTS
# {'val_acc': tensor(0.8438), 'val_loss': tensor(0.0224)}
# --------------------------------------------------------------------------------
# DATALOADER:137 TEST RESULTS
# {'val_acc': tensor(0.7188), 'val_loss': tensor(0.0454)}
# --------------------------------------------------------------------------------
# DATALOADER:138 TEST RESULTS
# {'val_acc': tensor(0.9688), 'val_loss': tensor(0.0054)}
# --------------------------------------------------------------------------------
# DATALOADER:139 TEST RESULTS
# {'val_acc': tensor(0.8438), 'val_loss': tensor(0.0283)}
# --------------------------------------------------------------------------------
# DATALOADER:140 TEST RESULTS
# {'val_acc': tensor(0.8438), 'val_loss': tensor(0.0225)}
# --------------------------------------------------------------------------------
# DATALOADER:141 TEST RESULTS
# {'val_acc': tensor(0.8750), 'val_loss': tensor(0.0158)}
# --------------------------------------------------------------------------------
# DATALOADER:142 TEST RESULTS
# {'val_acc': tensor(0.9062), 'val_loss': tensor(0.0155)}
# --------------------------------------------------------------------------------
# DATALOADER:143 TEST RESULTS
# {'val_acc': tensor(0.8438), 'val_loss': tensor(0.0202)}
# --------------------------------------------------------------------------------
# DATALOADER:144 TEST RESULTS
# {'val_acc': tensor(0.8750), 'val_loss': tensor(0.0207)}
# --------------------------------------------------------------------------------
# DATALOADER:145 TEST RESULTS
# {'val_acc': tensor(0.8438), 'val_loss': tensor(0.0221)}
# --------------------------------------------------------------------------------
# DATALOADER:146 TEST RESULTS
# {'val_acc': tensor(0.9062), 'val_loss': tensor(0.0133)}
# --------------------------------------------------------------------------------
# DATALOADER:147 TEST RESULTS
# {'val_acc': tensor(0.9062), 'val_loss': tensor(0.0156)}
# --------------------------------------------------------------------------------
# DATALOADER:148 TEST RESULTS
# {'val_acc': tensor(0.8125), 'val_loss': tensor(0.0258)}
# --------------------------------------------------------------------------------
# DATALOADER:149 TEST RESULTS
# {'val_acc': tensor(0.8125), 'val_loss': tensor(0.0276)}
# --------------------------------------------------------------------------------
# DATALOADER:150 TEST RESULTS
# {'val_acc': tensor(0.9688), 'val_loss': tensor(0.0064)}
# --------------------------------------------------------------------------------
# DATALOADER:151 TEST RESULTS
# {'val_acc': tensor(0.8438), 'val_loss': tensor(0.0251)}
# --------------------------------------------------------------------------------
# DATALOADER:152 TEST RESULTS
# {'val_acc': tensor(0.9688), 'val_loss': tensor(0.0083)}
# --------------------------------------------------------------------------------
# DATALOADER:153 TEST RESULTS
# {'val_acc': tensor(0.7812), 'val_loss': tensor(0.0303)}
# --------------------------------------------------------------------------------
# DATALOADER:154 TEST RESULTS
# {'val_acc': tensor(0.9062), 'val_loss': tensor(0.0108)}
# --------------------------------------------------------------------------------
# DATALOADER:155 TEST RESULTS
# {'val_acc': tensor(0.8750), 'val_loss': tensor(0.0208)}
# --------------------------------------------------------------------------------
# DATALOADER:156 TEST RESULTS
# {'val_acc': tensor(0.8125), 'val_loss': tensor(0.0238)}
# --------------------------------------------------------------------------------
# DATALOADER:157 TEST RESULTS
# {'val_acc': tensor(0.9062), 'val_loss': tensor(0.0110)}
# --------------------------------------------------------------------------------
# DATALOADER:158 TEST RESULTS
# {'val_acc': tensor(0.9688), 'val_loss': tensor(0.0028)}
# --------------------------------------------------------------------------------
# DATALOADER:159 TEST RESULTS
# {'val_acc': tensor(0.8438), 'val_loss': tensor(0.0195)}
# --------------------------------------------------------------------------------
# DATALOADER:160 TEST RESULTS
# {'val_acc': tensor(0.9062), 'val_loss': tensor(0.0139)}
# --------------------------------------------------------------------------------
# DATALOADER:161 TEST RESULTS
# {'val_acc': tensor(0.9375), 'val_loss': tensor(0.0097)}
# --------------------------------------------------------------------------------
# DATALOADER:162 TEST RESULTS
# {'val_acc': tensor(0.7812), 'val_loss': tensor(0.0291)}
# --------------------------------------------------------------------------------
# DATALOADER:163 TEST RESULTS
# {'val_acc': tensor(0.7812), 'val_loss': tensor(0.0289)}
# --------------------------------------------------------------------------------
# DATALOADER:164 TEST RESULTS
# {'val_acc': tensor(0.8750), 'val_loss': tensor(0.0157)}
# --------------------------------------------------------------------------------
# DATALOADER:165 TEST RESULTS
# {'val_acc': tensor(0.9375), 'val_loss': tensor(0.0125)}
# --------------------------------------------------------------------------------
# DATALOADER:166 TEST RESULTS
# {'val_acc': tensor(0.8438), 'val_loss': tensor(0.0165)}
# --------------------------------------------------------------------------------
# DATALOADER:167 TEST RESULTS
# {'val_acc': tensor(0.9062), 'val_loss': tensor(0.0121)}
# --------------------------------------------------------------------------------
# DATALOADER:168 TEST RESULTS
# {'val_acc': tensor(0.8750), 'val_loss': tensor(0.0167)}
# --------------------------------------------------------------------------------
# DATALOADER:169 TEST RESULTS
# {'val_acc': tensor(0.9062), 'val_loss': tensor(0.0131)}
# --------------------------------------------------------------------------------
# DATALOADER:170 TEST RESULTS
# {'val_acc': tensor(0.8750), 'val_loss': tensor(0.0183)}
# --------------------------------------------------------------------------------
# DATALOADER:171 TEST RESULTS
# {'val_acc': tensor(0.9062), 'val_loss': tensor(0.0119)}
# --------------------------------------------------------------------------------
# DATALOADER:172 TEST RESULTS
# {'val_acc': tensor(0.9062), 'val_loss': tensor(0.0143)}
# --------------------------------------------------------------------------------
# DATALOADER:173 TEST RESULTS
# {'val_acc': tensor(0.8750), 'val_loss': tensor(0.0172)}
# --------------------------------------------------------------------------------
# DATALOADER:174 TEST RESULTS
# {'val_acc': tensor(1.), 'val_loss': tensor(0.0017)}
# --------------------------------------------------------------------------------
# DATALOADER:175 TEST RESULTS
# {'val_acc': tensor(0.7812), 'val_loss': tensor(0.0290)}
# --------------------------------------------------------------------------------
# DATALOADER:176 TEST RESULTS
# {'val_acc': tensor(0.7812), 'val_loss': tensor(0.0321)}
# --------------------------------------------------------------------------------
# DATALOADER:177 TEST RESULTS
# {'val_acc': tensor(0.7812), 'val_loss': tensor(0.0353)}
# --------------------------------------------------------------------------------
# DATALOADER:178 TEST RESULTS
# {'val_acc': tensor(0.9062), 'val_loss': tensor(0.0150)}
# --------------------------------------------------------------------------------
# DATALOADER:179 TEST RESULTS
# {'val_acc': tensor(0.8125), 'val_loss': tensor(0.0241)}
# --------------------------------------------------------------------------------
# DATALOADER:180 TEST RESULTS
# {'val_acc': tensor(0.7812), 'val_loss': tensor(0.0283)}
# --------------------------------------------------------------------------------
# DATALOADER:181 TEST RESULTS
# {'val_acc': tensor(0.9375), 'val_loss': tensor(0.0085)}
# --------------------------------------------------------------------------------
# DATALOADER:182 TEST RESULTS
# {'val_acc': tensor(0.9062), 'val_loss': tensor(0.0116)}
# --------------------------------------------------------------------------------
# DATALOADER:183 TEST RESULTS
# {'val_acc': tensor(0.8438), 'val_loss': tensor(0.0258)}
# --------------------------------------------------------------------------------
# DATALOADER:184 TEST RESULTS
# {'val_acc': tensor(0.8438), 'val_loss': tensor(0.0262)}
# --------------------------------------------------------------------------------
# DATALOADER:185 TEST RESULTS
# {'val_acc': tensor(0.8125), 'val_loss': tensor(0.0307)}
# --------------------------------------------------------------------------------
# DATALOADER:186 TEST RESULTS
# {'val_acc': tensor(0.8750), 'val_loss': tensor(0.0230)}
# --------------------------------------------------------------------------------
# DATALOADER:187 TEST RESULTS
# {'val_acc': tensor(0.7812), 'val_loss': tensor(0.0371)}
# --------------------------------------------------------------------------------
# DATALOADER:188 TEST RESULTS
# {'val_acc': tensor(0.9375), 'val_loss': tensor(0.0129)}
# --------------------------------------------------------------------------------
# DATALOADER:189 TEST RESULTS
# {'val_acc': tensor(0.7500), 'val_loss': tensor(0.0325)}
# --------------------------------------------------------------------------------
# DATALOADER:190 TEST RESULTS
# {'val_acc': tensor(0.8125), 'val_loss': tensor(0.0257)}
# --------------------------------------------------------------------------------
# DATALOADER:191 TEST RESULTS
# {'val_acc': tensor(0.8438), 'val_loss': tensor(0.0229)}
# --------------------------------------------------------------------------------
# DATALOADER:192 TEST RESULTS
# {'val_acc': tensor(0.8438), 'val_loss': tensor(0.0254)}
# --------------------------------------------------------------------------------
# DATALOADER:193 TEST RESULTS
# {'val_acc': tensor(0.7500), 'val_loss': tensor(0.0337)}
# --------------------------------------------------------------------------------
# DATALOADER:194 TEST RESULTS
# {'val_acc': tensor(0.9062), 'val_loss': tensor(0.0122)}
# --------------------------------------------------------------------------------
# DATALOADER:195 TEST RESULTS
# {'val_acc': tensor(0.8750), 'val_loss': tensor(0.0179)}
# --------------------------------------------------------------------------------
# DATALOADER:196 TEST RESULTS
# {'val_acc': tensor(0.9062), 'val_loss': tensor(0.0115)}
# --------------------------------------------------------------------------------
# DATALOADER:197 TEST RESULTS
# {'val_acc': tensor(0.9062), 'val_loss': tensor(0.0123)}
# --------------------------------------------------------------------------------
# DATALOADER:198 TEST RESULTS
# {'val_acc': tensor(0.9062), 'val_loss': tensor(0.0155)}
# --------------------------------------------------------------------------------
# DATALOADER:199 TEST RESULTS
# {'val_acc': tensor(0.9688), 'val_loss': tensor(0.0047)}
# --------------------------------------------------------------------------------
# DATALOADER:200 TEST RESULTS
# {'val_acc': tensor(0.8125), 'val_loss': tensor(0.0282)}
# --------------------------------------------------------------------------------
# DATALOADER:201 TEST RESULTS
# {'val_acc': tensor(0.8750), 'val_loss': tensor(0.0189)}
# --------------------------------------------------------------------------------
# DATALOADER:202 TEST RESULTS
# {'val_acc': tensor(1.), 'val_loss': tensor(0.0001)}
# --------------------------------------------------------------------------------
# DATALOADER:203 TEST RESULTS
# {'val_acc': tensor(0.8438), 'val_loss': tensor(0.0220)}
# --------------------------------------------------------------------------------
# DATALOADER:204 TEST RESULTS
# {'val_acc': tensor(0.8438), 'val_loss': tensor(0.0202)}
# --------------------------------------------------------------------------------
# DATALOADER:205 TEST RESULTS
# {'val_acc': tensor(0.7500), 'val_loss': tensor(0.0338)}
# --------------------------------------------------------------------------------
# DATALOADER:206 TEST RESULTS
# {'val_acc': tensor(0.8125), 'val_loss': tensor(0.0276)}
# --------------------------------------------------------------------------------
# DATALOADER:207 TEST RESULTS
# {'val_acc': tensor(0.7500), 'val_loss': tensor(0.0350)}
# --------------------------------------------------------------------------------
# DATALOADER:208 TEST RESULTS
# {'val_acc': tensor(0.9062), 'val_loss': tensor(0.0143)}
# --------------------------------------------------------------------------------
# DATALOADER:209 TEST RESULTS
# {'val_acc': tensor(0.9688), 'val_loss': tensor(0.0030)}
# --------------------------------------------------------------------------------
# DATALOADER:210 TEST RESULTS
# {'val_acc': tensor(0.9062), 'val_loss': tensor(0.0119)}
# --------------------------------------------------------------------------------
# DATALOADER:211 TEST RESULTS
# {'val_acc': tensor(0.9062), 'val_loss': tensor(0.0160)}
# --------------------------------------------------------------------------------
# DATALOADER:212 TEST RESULTS
# {'val_acc': tensor(0.9062), 'val_loss': tensor(0.0108)}
# --------------------------------------------------------------------------------
# DATALOADER:213 TEST RESULTS
# {'val_acc': tensor(0.8125), 'val_loss': tensor(0.0272)}
# --------------------------------------------------------------------------------
# DATALOADER:214 TEST RESULTS
# {'val_acc': tensor(0.9062), 'val_loss': tensor(0.0121)}
# --------------------------------------------------------------------------------
# DATALOADER:215 TEST RESULTS
# {'val_acc': tensor(0.9062), 'val_loss': tensor(0.0131)}
# --------------------------------------------------------------------------------
# DATALOADER:216 TEST RESULTS
# {'val_acc': tensor(0.8125), 'val_loss': tensor(0.0293)}
# --------------------------------------------------------------------------------
# DATALOADER:217 TEST RESULTS
# {'val_acc': tensor(0.9375), 'val_loss': tensor(0.0086)}
# --------------------------------------------------------------------------------
# DATALOADER:218 TEST RESULTS
# {'val_acc': tensor(0.9062), 'val_loss': tensor(0.0165)}
# --------------------------------------------------------------------------------
# DATALOADER:219 TEST RESULTS
# {'val_acc': tensor(0.8125), 'val_loss': tensor(0.0235)}
# --------------------------------------------------------------------------------
# DATALOADER:220 TEST RESULTS
# {'val_acc': tensor(0.9062), 'val_loss': tensor(0.0157)}
# --------------------------------------------------------------------------------
# DATALOADER:221 TEST RESULTS
# {'val_acc': tensor(0.9062), 'val_loss': tensor(0.0111)}
# --------------------------------------------------------------------------------
# DATALOADER:222 TEST RESULTS
# {'val_acc': tensor(0.9375), 'val_loss': tensor(0.0082)}
# --------------------------------------------------------------------------------
# DATALOADER:223 TEST RESULTS
# {'val_acc': tensor(0.9062), 'val_loss': tensor(0.0154)}
# --------------------------------------------------------------------------------
# DATALOADER:224 TEST RESULTS
# {'val_acc': tensor(0.9062), 'val_loss': tensor(0.0125)}
# --------------------------------------------------------------------------------
# DATALOADER:225 TEST RESULTS
# {'val_acc': tensor(0.9062), 'val_loss': tensor(0.0162)}
# --------------------------------------------------------------------------------
# DATALOADER:226 TEST RESULTS
# {'val_acc': tensor(0.9688), 'val_loss': tensor(0.0073)}
# --------------------------------------------------------------------------------
# DATALOADER:227 TEST RESULTS
# {'val_acc': tensor(0.9062), 'val_loss': tensor(0.0144)}
# --------------------------------------------------------------------------------
# DATALOADER:228 TEST RESULTS
# {'val_acc': tensor(0.8438), 'val_loss': tensor(0.0212)}
# --------------------------------------------------------------------------------
# DATALOADER:229 TEST RESULTS
# {'val_acc': tensor(0.8750), 'val_loss': tensor(0.0161)}
# --------------------------------------------------------------------------------
# DATALOADER:230 TEST RESULTS
# {'val_acc': tensor(0.9062), 'val_loss': tensor(0.0122)}
# --------------------------------------------------------------------------------
# DATALOADER:231 TEST RESULTS
# {'val_acc': tensor(0.9375), 'val_loss': tensor(0.0089)}
# --------------------------------------------------------------------------------
# DATALOADER:232 TEST RESULTS
# {'val_acc': tensor(0.9062), 'val_loss': tensor(0.0162)}
# --------------------------------------------------------------------------------
# DATALOADER:233 TEST RESULTS
# {'val_acc': tensor(0.7812), 'val_loss': tensor(0.0317)}
# --------------------------------------------------------------------------------
# DATALOADER:234 TEST RESULTS
# {'val_acc': tensor(0.8438), 'val_loss': tensor(0.0206)}
# --------------------------------------------------------------------------------
# DATALOADER:235 TEST RESULTS
# {'val_acc': tensor(0.9062), 'val_loss': tensor(0.0146)}
# --------------------------------------------------------------------------------
# DATALOADER:236 TEST RESULTS
# {'val_acc': tensor(0.8438), 'val_loss': tensor(0.0190)}
# --------------------------------------------------------------------------------
# DATALOADER:237 TEST RESULTS
# {'val_acc': tensor(0.8125), 'val_loss': tensor(0.0261)}
# --------------------------------------------------------------------------------
# DATALOADER:238 TEST RESULTS
# {'val_acc': tensor(0.9062), 'val_loss': tensor(0.0167)}
# --------------------------------------------------------------------------------
# DATALOADER:239 TEST RESULTS
# {'val_acc': tensor(0.9062), 'val_loss': tensor(0.0145)}
# --------------------------------------------------------------------------------
# DATALOADER:240 TEST RESULTS
# {'val_acc': tensor(0.8125), 'val_loss': tensor(0.0259)}
# --------------------------------------------------------------------------------
# DATALOADER:241 TEST RESULTS
# {'val_acc': tensor(0.9688), 'val_loss': tensor(0.0063)}
# --------------------------------------------------------------------------------
# DATALOADER:242 TEST RESULTS
# {'val_acc': tensor(0.8750), 'val_loss': tensor(0.0176)}
# --------------------------------------------------------------------------------
# DATALOADER:243 TEST RESULTS
# {'val_acc': tensor(0.9688), 'val_loss': tensor(0.0058)}
# --------------------------------------------------------------------------------
# DATALOADER:244 TEST RESULTS
# {'val_acc': tensor(0.8438), 'val_loss': tensor(0.0224)}
# --------------------------------------------------------------------------------
# DATALOADER:245 TEST RESULTS
# {'val_acc': tensor(0.8125), 'val_loss': tensor(0.0274)}
# --------------------------------------------------------------------------------
# DATALOADER:246 TEST RESULTS
# {'val_acc': tensor(0.7812), 'val_loss': tensor(0.0310)}
# ...
# --------------------------------------------------------------------------------
# DATALOADER:218 TEST RESULTS
# {'val_acc': tensor(0.1562), 'val_loss': tensor(0.1392)}
# --------------------------------------------------------------------------------
# DATALOADER:219 TEST RESULTS
# {'val_acc': tensor(0.2188), 'val_loss': tensor(0.1354)}
# --------------------------------------------------------------------------------
# DATALOADER:220 TEST RESULTS
# {'val_acc': tensor(0.0938), 'val_loss': tensor(0.1468)}
# --------------------------------------------------------------------------------
# DATALOADER:221 TEST RESULTS
# {'val_acc': tensor(0.2188), 'val_loss': tensor(0.1284)}
# --------------------------------------------------------------------------------
# DATALOADER:222 TEST RESULTS
# {'val_acc': tensor(0.2500), 'val_loss': tensor(0.1178)}
# --------------------------------------------------------------------------------
# DATALOADER:223 TEST RESULTS
# {'val_acc': tensor(0.1250), 'val_loss': tensor(0.1443)}
# --------------------------------------------------------------------------------
# DATALOADER:224 TEST RESULTS
# {'val_acc': tensor(0.4062), 'val_loss': tensor(0.1019)}
# --------------------------------------------------------------------------------
# DATALOADER:225 TEST RESULTS
# {'val_acc': tensor(0.1562), 'val_loss': tensor(0.1262)}
# --------------------------------------------------------------------------------
# DATALOADER:226 TEST RESULTS
# {'val_acc': tensor(0.0938), 'val_loss': tensor(0.1516)}
# --------------------------------------------------------------------------------
# DATALOADER:227 TEST RESULTS
# {'val_acc': tensor(0.1562), 'val_loss': tensor(0.1282)}
# --------------------------------------------------------------------------------
# DATALOADER:228 TEST RESULTS
# {'val_acc': tensor(0.3125), 'val_loss': tensor(0.1015)}
# --------------------------------------------------------------------------------
# DATALOADER:229 TEST RESULTS
# {'val_acc': tensor(0.2500), 'val_loss': tensor(0.1312)}
# --------------------------------------------------------------------------------
# DATALOADER:230 TEST RESULTS
# {'val_acc': tensor(0.1875), 'val_loss': tensor(0.1348)}
# --------------------------------------------------------------------------------
# DATALOADER:231 TEST RESULTS
# {'val_acc': tensor(0.1875), 'val_loss': tensor(0.1345)}
# --------------------------------------------------------------------------------
# DATALOADER:232 TEST RESULTS
# {'val_acc': tensor(0.2188), 'val_loss': tensor(0.1219)}
# --------------------------------------------------------------------------------
# DATALOADER:233 TEST RESULTS
# {'val_acc': tensor(0.1250), 'val_loss': tensor(0.1358)}
# --------------------------------------------------------------------------------
# DATALOADER:234 TEST RESULTS
# {'val_acc': tensor(0.3438), 'val_loss': tensor(0.0906)}
# --------------------------------------------------------------------------------
# DATALOADER:235 TEST RESULTS
# {'val_acc': tensor(0.2500), 'val_loss': tensor(0.1129)}
# --------------------------------------------------------------------------------
# DATALOADER:236 TEST RESULTS
# {'val_acc': tensor(0.2812), 'val_loss': tensor(0.1124)}
# --------------------------------------------------------------------------------
# DATALOADER:237 TEST RESULTS
# {'val_acc': tensor(0.1875), 'val_loss': tensor(0.1242)}
# --------------------------------------------------------------------------------
# DATALOADER:238 TEST RESULTS
# {'val_acc': tensor(0.2188), 'val_loss': tensor(0.1319)}
# --------------------------------------------------------------------------------
# DATALOADER:239 TEST RESULTS
# {'val_acc': tensor(0.0938), 'val_loss': tensor(0.1344)}
# --------------------------------------------------------------------------------
# DATALOADER:240 TEST RESULTS
# {'val_acc': tensor(0.0625), 'val_loss': tensor(0.1412)}
# --------------------------------------------------------------------------------
# DATALOADER:241 TEST RESULTS
# {'val_acc': tensor(0.2500), 'val_loss': tensor(0.1207)}
# --------------------------------------------------------------------------------
# DATALOADER:242 TEST RESULTS
# {'val_acc': tensor(0.2188), 'val_loss': tensor(0.1277)}
# --------------------------------------------------------------------------------
# DATALOADER:243 TEST RESULTS
# {'val_acc': tensor(0.2188), 'val_loss': tensor(0.1334)}
# --------------------------------------------------------------------------------
# DATALOADER:244 TEST RESULTS
# {'val_acc': tensor(0.1562), 'val_loss': tensor(0.1375)}
# --------------------------------------------------------------------------------
# DATALOADER:245 TEST RESULTS
# {'val_acc': tensor(0.2188), 'val_loss': tensor(0.1365)}
# --------------------------------------------------------------------------------
# DATALOADER:246 TEST RESULTS
# {'val_acc': tensor(0.1250), 'val_loss': tensor(0.1429)}
# --------------------------------------------------------------------------------
# DATALOADER:247 TEST RESULTS
# {'val_acc': tensor(0.1250), 'val_loss': tensor(0.1455)}
# --------------------------------------------------------------------------------
# DATALOADER:248 TEST RESULTS
# {'val_acc': tensor(0.1875), 'val_loss': tensor(0.1319)}
# --------------------------------------------------------------------------------
# DATALOADER:249 TEST RESULTS
# {'val_acc': tensor(0.1875), 'val_loss': tensor(0.1278)}
# --------------------------------------------------------------------------------
# DATALOADER:250 TEST RESULTS
# {'val_acc': tensor(0.1250), 'val_loss': tensor(0.1514)}
# --------------------------------------------------------------------------------
# DATALOADER:251 TEST RESULTS
# {'val_acc': tensor(0.1562), 'val_loss': tensor(0.1434)}
# --------------------------------------------------------------------------------
# DATALOADER:252 TEST RESULTS
# {'val_acc': tensor(0.1875), 'val_loss': tensor(0.1366)}
# --------------------------------------------------------------------------------
# DATALOADER:253 TEST RESULTS
# {'val_acc': tensor(0.2188), 'val_loss': tensor(0.1308)}
# --------------------------------------------------------------------------------
# DATALOADER:254 TEST RESULTS
# {'val_acc': tensor(0.2188), 'val_loss': tensor(0.1299)}
# --------------------------------------------------------------------------------
# DATALOADER:255 TEST RESULTS
# {'val_acc': tensor(0.2500), 'val_loss': tensor(0.1175)}
# --------------------------------------------------------------------------------
# DATALOADER:256 TEST RESULTS
# {'val_acc': tensor(0.2812), 'val_loss': tensor(0.1166)}
# --------------------------------------------------------------------------------
# DATALOADER:257 TEST RESULTS
# {'val_acc': tensor(0.2188), 'val_loss': tensor(0.1358)}
# --------------------------------------------------------------------------------
# DATALOADER:258 TEST RESULTS
# {'val_acc': tensor(0.1250), 'val_loss': tensor(0.1435)}
# --------------------------------------------------------------------------------
# DATALOADER:259 TEST RESULTS
# {'val_acc': tensor(0.2500), 'val_loss': tensor(0.1291)}
# --------------------------------------------------------------------------------
# DATALOADER:260 TEST RESULTS
# {'val_acc': tensor(0.1875), 'val_loss': tensor(0.1385)}
# --------------------------------------------------------------------------------
# DATALOADER:261 TEST RESULTS
# {'val_acc': tensor(0.1562), 'val_loss': tensor(0.1329)}
# --------------------------------------------------------------------------------
# DATALOADER:262 TEST RESULTS
# {'val_acc': tensor(0.1250), 'val_loss': tensor(0.1428)}
# --------------------------------------------------------------------------------
# DATALOADER:263 TEST RESULTS
# {'val_acc': tensor(0.1562), 'val_loss': tensor(0.1461)}
# --------------------------------------------------------------------------------
# DATALOADER:264 TEST RESULTS
# {'val_acc': tensor(0.0938), 'val_loss': tensor(0.1435)}
# --------------------------------------------------------------------------------
# DATALOADER:265 TEST RESULTS
# {'val_acc': tensor(0.0625), 'val_loss': tensor(0.1473)}
# --------------------------------------------------------------------------------
# DATALOADER:266 TEST RESULTS
# {'val_acc': tensor(0.1562), 'val_loss': tensor(0.1457)}
# --------------------------------------------------------------------------------
# DATALOADER:267 TEST RESULTS
# {'val_acc': tensor(0.1250), 'val_loss': tensor(0.1354)}
# --------------------------------------------------------------------------------
# DATALOADER:268 TEST RESULTS
# {'val_acc': tensor(0.1250), 'val_loss': tensor(0.1371)}
# --------------------------------------------------------------------------------
# DATALOADER:269 TEST RESULTS
# {'val_acc': tensor(0.2188), 'val_loss': tensor(0.1221)}
# --------------------------------------------------------------------------------
# DATALOADER:270 TEST RESULTS
# {'val_acc': tensor(0.2500), 'val_loss': tensor(0.1247)}
# --------------------------------------------------------------------------------
# DATALOADER:271 TEST RESULTS
# {'val_acc': tensor(0.2812), 'val_loss': tensor(0.1191)}
# --------------------------------------------------------------------------------
# DATALOADER:272 TEST RESULTS
# {'val_acc': tensor(0.2188), 'val_loss': tensor(0.1226)}
# --------------------------------------------------------------------------------
# DATALOADER:273 TEST RESULTS
# {'val_acc': tensor(0.1250), 'val_loss': tensor(0.1468)}
# --------------------------------------------------------------------------------
# DATALOADER:274 TEST RESULTS
# {'val_acc': tensor(0.1250), 'val_loss': tensor(0.1500)}
# --------------------------------------------------------------------------------
# DATALOADER:275 TEST RESULTS
# {'val_acc': tensor(0.2500), 'val_loss': tensor(0.1221)}
# --------------------------------------------------------------------------------
# DATALOADER:276 TEST RESULTS
# {'val_acc': tensor(0.2500), 'val_loss': tensor(0.1217)}
# --------------------------------------------------------------------------------
# DATALOADER:277 TEST RESULTS
# {'val_acc': tensor(0.1562), 'val_loss': tensor(0.1425)}
# --------------------------------------------------------------------------------
# DATALOADER:278 TEST RESULTS
# {'val_acc': tensor(0.2500), 'val_loss': tensor(0.1215)}
# --------------------------------------------------------------------------------
# DATALOADER:279 TEST RESULTS
# {'val_acc': tensor(0.1250), 'val_loss': tensor(0.1466)}
# --------------------------------------------------------------------------------
# DATALOADER:280 TEST RESULTS
# {'val_acc': tensor(0.2500), 'val_loss': tensor(0.1193)}
# --------------------------------------------------------------------------------
# DATALOADER:281 TEST RESULTS
# {'val_acc': tensor(0.2812), 'val_loss': tensor(0.1189)}
# --------------------------------------------------------------------------------
# DATALOADER:282 TEST RESULTS
# {'val_acc': tensor(0.0312), 'val_loss': tensor(0.1636)}
# --------------------------------------------------------------------------------
# DATALOADER:283 TEST RESULTS
# {'val_acc': tensor(0.1875), 'val_loss': tensor(0.1312)}
# --------------------------------------------------------------------------------
# DATALOADER:284 TEST RESULTS
# {'val_acc': tensor(0.2500), 'val_loss': tensor(0.1322)}
# --------------------------------------------------------------------------------
# DATALOADER:285 TEST RESULTS
# {'val_acc': tensor(0.2188), 'val_loss': tensor(0.1277)}
# --------------------------------------------------------------------------------
# DATALOADER:286 TEST RESULTS
# {'val_acc': tensor(0.1875), 'val_loss': tensor(0.1369)}
# --------------------------------------------------------------------------------
# DATALOADER:287 TEST RESULTS
# {'val_acc': tensor(0.0938), 'val_loss': tensor(0.1467)}
# --------------------------------------------------------------------------------
# DATALOADER:288 TEST RESULTS
# {'val_acc': tensor(0.2188), 'val_loss': tensor(0.1228)}
# --------------------------------------------------------------------------------
# DATALOADER:289 TEST RESULTS
# {'val_acc': tensor(0.1875), 'val_loss': tensor(0.1277)}
# --------------------------------------------------------------------------------
# DATALOADER:290 TEST RESULTS
# {'val_acc': tensor(0.0938), 'val_loss': tensor(0.1411)}
# --------------------------------------------------------------------------------
# DATALOADER:291 TEST RESULTS
# {'val_acc': tensor(0.0938), 'val_loss': tensor(0.1487)}
# --------------------------------------------------------------------------------
# DATALOADER:292 TEST RESULTS
# {'val_acc': tensor(0.1562), 'val_loss': tensor(0.1420)}
# --------------------------------------------------------------------------------
# DATALOADER:293 TEST RESULTS
# {'val_acc': tensor(0.1562), 'val_loss': tensor(0.1394)}
# --------------------------------------------------------------------------------
# DATALOADER:294 TEST RESULTS
# {'val_acc': tensor(0.3438), 'val_loss': tensor(0.1098)}
# --------------------------------------------------------------------------------
# DATALOADER:295 TEST RESULTS
# {'val_acc': tensor(0.0938), 'val_loss': tensor(0.1515)}
# --------------------------------------------------------------------------------
# DATALOADER:296 TEST RESULTS
# {'val_acc': tensor(0.1875), 'val_loss': tensor(0.1321)}
# --------------------------------------------------------------------------------
# DATALOADER:297 TEST RESULTS
# {'val_acc': tensor(0.2188), 'val_loss': tensor(0.1248)}
# --------------------------------------------------------------------------------
# DATALOADER:298 TEST RESULTS
# {'val_acc': tensor(0.2188), 'val_loss': tensor(0.1280)}
# --------------------------------------------------------------------------------
# DATALOADER:299 TEST RESULTS
# {'val_acc': tensor(0.2188), 'val_loss': tensor(0.1297)}
# --------------------------------------------------------------------------------
# DATALOADER:300 TEST RESULTS
# {'val_acc': tensor(0.0625), 'val_loss': tensor(0.1496)}
# --------------------------------------------------------------------------------
# DATALOADER:301 TEST RESULTS
# {'val_acc': tensor(0.1250), 'val_loss': tensor(0.1366)}
# --------------------------------------------------------------------------------
# DATALOADER:302 TEST RESULTS
# {'val_acc': tensor(0.1875), 'val_loss': tensor(0.1224)}
# --------------------------------------------------------------------------------
# DATALOADER:303 TEST RESULTS
# {'val_acc': tensor(0.0938), 'val_loss': tensor(0.1432)}
# --------------------------------------------------------------------------------
# DATALOADER:304 TEST RESULTS
# {'val_acc': tensor(0.2188), 'val_loss': tensor(0.1264)}
# --------------------------------------------------------------------------------
# DATALOADER:305 TEST RESULTS
# {'val_acc': tensor(0.2812), 'val_loss': tensor(0.1148)}
# --------------------------------------------------------------------------------
# DATALOADER:306 TEST RESULTS
# {'val_acc': tensor(0.1250), 'val_loss': tensor(0.1400)}
# --------------------------------------------------------------------------------
# DATALOADER:307 TEST RESULTS
# {'val_acc': tensor(0.0938), 'val_loss': tensor(0.1433)}
# --------------------------------------------------------------------------------
# DATALOADER:308 TEST RESULTS
# {'val_acc': tensor(0.2188), 'val_loss': tensor(0.1233)}
# --------------------------------------------------------------------------------
# DATALOADER:309 TEST RESULTS
# {'val_acc': tensor(0.1875), 'val_loss': tensor(0.1344)}
# --------------------------------------------------------------------------------
# DATALOADER:310 TEST RESULTS
# {'val_acc': tensor(0.1250), 'val_loss': tensor(0.1396)}
# --------------------------------------------------------------------------------
# DATALOADER:311 TEST RESULTS
# {'val_acc': tensor(0.2188), 'val_loss': tensor(0.1336)}
# --------------------------------------------------------------------------------
# DATALOADER:312 TEST RESULTS
# {'val_acc': tensor(0.1250), 'val_loss': tensor(0.1379)}
# --------------------------------------------------------------------------------
# DATALOADER:313 TEST RESULTS
# {'val_acc': tensor(0.0625), 'val_loss': tensor(0.1481)}
# --------------------------------------------------------------------------------
# Testing: 100%|##########| 313/313 [03:05<00:00,  1.68it/s]

# %%
# fcn_acc_diag = np.mean([x["val_acc"] for x in fcn_tests[0]])
# fcn_acc_rand = np.mean([x["val_acc"] for x in fcn_tests[1]])
cnn_acc_diag = np.mean([x["val_acc"] for x in cnn_tests[0]])
cnn_acc_rand = np.mean([x["val_acc"] for x in cnn_tests[1]])
lcn_acc_diag = np.mean([x["val_acc"] for x in lcn_tests[0]])
lcn_acc_rand = np.mean([x["val_acc"] for x in lcn_tests[1]])
print(f"CNN accuracy on diag test data:   {cnn_acc_diag:<6.3f}")
print(f"CNN accuracy on sparse test data: {cnn_acc_rand:<6.3f}")
print(f"LCN accuracy on diag test data:   {lcn_acc_diag:<6.3f}")
print(f"LCN accuracy on sparse test data: {lcn_acc_rand:<6.3f}")
# print(f"FCN accuracy on diag test data:   {fcn_acc_diag:<6.3f}")
# print(f"FCN accuracy on sparse test data: {fcn_acc_rand:<6.3f}")
# Out:
# CNN accuracy on diag test data:   0.848
# CNN accuracy on sparse test data: 0.859
# LCN accuracy on diag test data:   0.791
# LCN accuracy on sparse test data: 0.179
